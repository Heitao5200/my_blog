# %% [markdown]
# ## 扩展词与扩展查询（进阶方向）
#
# 查询改写（Query Rewriting，或称为查询扩展Query Expansion）。查询改写的应用方式是对原始Query拓展出与用户需求关联度高的改写词，多个改写词与用户搜索词一起做检索，从而用更好的表述，帮用户搜到更多符合要求的文本。
#
# - 语义拓展：主要是同义词、下位词以及常见的大小写数字和繁简转化等，例如“理发”、“剪发”、“造型”、“发艺”、“美发”、“剪头”等等。
#     - 用户表达和商家表达上的Gap：非语言上的同义。如用户表述口语化“学吉他”，商户描述书面化“吉他培训”；用户输入不完全匹配商户名：“希尔顿大酒店”（商家更常见的描述为“希尔顿酒店”）。
# - 场景拓展：例如“摘草莓”在美团的搜索场景下，用户基于对平台的认知对应需求是“草莓园”。
# - 其他漏召回问题：部分的多字少字、纠错等问题，如“房屋扫”对应“家政保洁”的需求；理论上查询改写可以通过增加改写词解决所有漏召回问题，诸如“冬日四件套”包括“冰糖葫芦、烤地瓜、炒栗子、热奶茶”这类有时效性的网红概念，也可以通过改写进行解决。

# %%
import time 
import jwt
import requests
import jieba
import re
from tqdm import tqdm
import json
import pdfplumber
from langchain.schema import Document
from rank_bm25 import BM25Okapi
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer
 

def extract_page_text(filepath, max_len=256, overlap_len=100):
    page_content  = []
    pdf =pdfplumber.open(filepath)
    page_count = 0
    # pattern = r'^\d{1,3}'
    for page in tqdm(pdf.pages):
        page_text = page.extract_text().strip()
        raw_text = [text.strip() for text in page_text.split('\n')]
        new_text = '\n'.join(raw_text)
        new_text = re.sub(r'\n\d{2,3}\s?', '\n', new_text)
        # new_text = re.sub(pattern, '', new_text).strip()
        if len(new_text)>10 and '..............' not in new_text:
            page_content.append(new_text)
        else:
            page_content.append('  ')

    cleaned_chunks = []
    i = 0
    all_str = ''.join(page_content)
    all_str = all_str.replace('\n', '')
    while i<len(all_str):
        cur_s = all_str[i:i+max_len]
        if len(cur_s)>10:
            cleaned_chunks.append(Document(page_content=cur_s, metadata={'page':page_count+1}))
        i+=(max_len - overlap_len)

    return cleaned_chunks,page_content
# 实际KEY，过期时间
def generate_token(apikey: str, exp_seconds: int):
    try:
        id, secret = apikey.split(".")
    except Exception as e:
        raise Exception("invalid apikey", e)

    payload = {
        "api_key": id,
        "exp": int(round(time.time() * 1000)) + exp_seconds * 1000,
        "timestamp": int(round(time.time() * 1000)),
    }
    return jwt.encode(
        payload,
        secret,
        algorithm="HS256",
        headers={"alg": "HS256", "sign_type": "SIGN"},
    )
def ask_glm(content):
    url = "https://open.bigmodel.cn/api/paas/v4/chat/completions"
    headers = {
      'Content-Type': 'application/json',
      'Authorization': generate_token("f1a0b6c3d36d46d3eed74a6c7de3e9e4.pZ88EkbBscyHXXcJ", 1000)
    }

    data = {
        "model": "glm-4",
        "messages": [{"role": "user", "content": content}]
    }

    response = requests.post(url, headers=headers, json=data)
    return response.json()



def get_answer_from_llm(question_idx,questions):
    for query_idx in question_idx:
        doc_scores = bm25.get_scores(jieba.lcut(questions[query_idx]["question"]))
        max_score_page_idxs = doc_scores.argsort()[-3:]

        pairs = []
        for idx in max_score_page_idxs:
            pairs.append([questions[query_idx]["question"], pdf_content[idx] ])

        inputs = tokenizer(pairs, padding=True, truncation=True, return_tensors='pt', max_length=512)
        with torch.no_grad():
            inputs = {key: inputs[key].cuda() for key in inputs.keys()}
            scores = rerank_model(**inputs, return_dict=True).logits.view(-1, ).float()
        max_score_page_idx = max_score_page_idxs[scores.cpu().numpy().argmax()]
        questions[query_idx]['reference'] = 'page_' + str(max_score_page_idx + 1)

        prompt= '''你是一个汽车维修和汽车销售的专家，将用户的提问改为含义相近当不相同的句子,将改写后的句子以list的形式返回，不要输出起他无关内容,举一个例子：[改写后的句子1,改写后的句子2...] ：
           问题：{0}
        '''.format(
            # ''.join([f'第{i+1}页内容：' + pdf_content[i].replace('\n', '') + '\n' for i in doc_scores.argsort()[-3:]]) ,
            questions[query_idx]["question"]
        )

        answer = ask_glm(prompt)['choices'][0]['message']['content']
        # if '无法回答' in answer:
        #     answer = ask_glm(prompt2)['choices'][0]['message']['content']
        questions[query_idx]['question_rewriting'] = answer
        print(query_idx,questions[query_idx])
    return questions

def get_questions_from_file(file_path):
    with open(f'/root/code/submit_task8_glm4.json', 'r', encoding='utf8') as f:
        questions = f.read()
    questions = eval(questions)
    return questions

def get_useless_question_idx(questions):
    ## 收集无法回答答案的问题的索引
    useless_question_idx = []
    for i,question in enumerate(questions):
        if '无法回答' in question['answer']:
            # print(question)
            useless_question_idx.append(i)
    return useless_question_idx





# file_path = '/root/code/submit_task8_glm4.json'
questions = json.load(open("./data/questions.json"))
filepath = './data/初赛训练数据集.pdf'
_,pdf_content = extract_page_text(filepath, max_len=256, overlap_len=100)


tokenizer = AutoTokenizer.from_pretrained('/root/code/quietnight/bge-reranker-large/')
rerank_model = AutoModelForSequenceClassification.from_pretrained('/root/code/quietnight/bge-reranker-large/')
rerank_model.cuda()


pdf_content_words = [jieba.lcut(x ) for x in pdf_content]
bm25 = BM25Okapi(pdf_content_words)
# Out:
# 100%|██████████| 354/354 [00:07<00:00, 49.91it/s]

# %%
with open(f'task9_questions.json', 'r', encoding='utf8') as up:
    task9_questions = eval(up.read())

# %%
def get_answer_from_llm(question_idx,questions):
    for query_idx in question_idx:
        doc_scores = bm25.get_scores(jieba.lcut(questions[query_idx]["question"]))
        max_score_page_idxs = doc_scores.argsort()[-3:]

        pairs = []
        for idx in max_score_page_idxs:
            pairs.append([questions[query_idx]["question"], pdf_content[idx] ])

        inputs = tokenizer(pairs, padding=True, truncation=True, return_tensors='pt', max_length=512)
        with torch.no_grad():
            inputs = {key: inputs[key].cuda() for key in inputs.keys()}
            scores = rerank_model(**inputs, return_dict=True).logits.view(-1, ).float()
        max_score_page_idx = max_score_page_idxs[scores.cpu().numpy().argmax()]
        questions[query_idx]['reference'] = 'page_' + str(max_score_page_idx + 1)

        prompt= '''你是一个汽车专家，帮我结合给定的资料与关键词和改写后的问题，回答所给的问题。如果问题无法从资料中获得，请输出:结合给定的资料，无法回答问题。
            资料:{0}

            关键词:{1}

            改写后的问题:{2}

            问题：{3}
                '''.format(
                    ''.join([f'第{i+1}页内容：' + pdf_content[i].replace('\n', '') + '\n' for i in doc_scores.argsort()[-5:]]) ,
                    questions[query_idx]["question_keywords"],
                    questions[query_idx]["question_rewriting"],
                    questions[query_idx]["question"],
                )

        answer = ask_glm(prompt)['choices'][0]['message']['content']
        # if '无法回答' in answer:
        #     answer = ask_glm(prompt2)['choices'][0]['message']['content']
        questions[query_idx]['answer'] = answer
        print(query_idx,questions[query_idx])
    return questions

# %%
def clean_question_rewrite(question_rewrite):
    question_rewrite = question_rewrite.replace('“','"').replace('”','"').replace('，',',').replace('？','?').replace(']\n[',',').replace('："','"')
    question_rewrite = question_rewrite.replace('改写后的句子','')
    question_rewrite = question_rewrite.replace('1"','"').replace('2"','"').replace('3"','"').replace('4"','"')
    return question_rewrite
bad_question = []
for idx,question in enumerate(task9_questions):
    question_rewrite = task9_questions[idx]['question_rewriting']
    task9_questions[idx]['question_rewriting'] = clean_question_rewrite(question_rewrite)
    try:
        eval(clean_question_rewrite(question_rewrite))
    except:
        bad_question.append(idx)
        print(question_rewrite)

# %%
task9_questions = get_answer_from_llm(range(len(task9_questions)),task9_questions )
# Out:
# 0 {'question': '“前排座椅通风”的相关内容在第几页？', 'answer': '“前排座椅通风”的相关内容在第115页、第116页和第117页中都有提及。', 'reference': 'page_117', 'question_keywords': '前排座椅通风\n', 'question_rewriting': '前排座椅通风的相关内容在第115页、第116页和第117页中都有提及。'}
# 1 {'question': '"关于车辆的儿童安全座椅固定装置，在哪一页可以找到相关内容？"', 'answer': '关于车辆的儿童安全座椅固定装置的相关内容，可以在用户手册的第123页和第124页找到。这些页面提供了儿童安全座椅的安装说明、固定方法和相关安全警告。', 'reference': 'page_123', 'question_keywords': '儿童安全座椅 固定装置 相关内容', 'question_rewriting': '["车辆儿童安全座椅的安装说明在手册的哪一页有所介绍?","我想了解车辆中儿童安全座椅固定设备的信息,能告诉我具体在哪一页吗?","在用户手册的哪一部分可以查阅到车辆儿童安全座椅的固定方法?","我想查找关于汽车内置儿童座椅固定系统的说明,能指出手册中对应的页码吗?"]'}
# 2 {'question': '“打开前机舱盖”的相关信息在第几页？', 'answer': '"打开前机舱盖"的相关信息在第308页。', 'reference': 'page_307', 'question_keywords': '打开 前机舱盖 相关信息 页码', 'question_rewriting': '["请问在哪一页可以找到开启引擎盖的相关资料?","我想要了解如何打开汽车前盖的信息,这在手册的第几页?","能告诉我查看打开车辆前引擎盖步骤的页面号码是多少吗?","在哪一页可以查阅到关于车辆前部机盖开启的说明?"]'}
# 3 {'question': '“打开前机舱盖”这个操作在哪一页？', 'answer': '根据给定的资料，关于“打开前机舱盖”的操作说明可以在第308页找到。该页面详细描述了如何抬起、轻抬前机舱盖前边缘，并确保其完全关闭的步骤，同时也包含了关闭前机舱盖时的注意事项。', 'reference': 'page_307', 'question_keywords': '打开 前机舱盖 操作 页面', 'question_rewriting': '["在哪一页可以找到打开车辆前引擎盖的说明?"\n"关于如何开启汽车前盖的操作,具体在用户手册的哪一页?"\n"我想了解如何进行开前机舱盖的动作,这个步骤在手册的哪一部分?"\n"在用户指南中,打开车辆前部引擎舱盖的步骤是在哪一页展示的?"]'}
# 4 {'question': '“查看行车记录仪视频”这一项内容在第几页？', 'answer': '根据给定的资料，"查看行车记录仪视频"这一项内容在第275页和第276页有详细说明。在第275页中，可以通过点击图标进入相册界面，并设置行车记录仪的分辨率和循环录像时间，同时可以查看行车记录仪的视频。在第276页中，可以通过点击"DVR"按键进入DVR相册界面，选择并查看行车记录仪视频。因此，查看行车记录仪视频的选项可以在第275页和第276页找到。', 'reference': 'page_275', 'question_keywords': '查看 行车记录仪 视频 第几页', 'question_rewriting': '["行车记录仪视频查看功能位于哪一页?","在哪个页面可以找到查看行车记录仪的视频选项?"]'}
# 5 {'question': '请问Lynk&Co领克汽车的事件数据记录系统（EDR）主要记录哪些信息？', 'answer': 'Lynk&Co领克汽车的事件数据记录系统（EDR）主要记录以下信息：车辆的行驶速度（表示事件发生时刻车辆速度），制动状态（表示事件发生时刻车辆是否制动）。此外，根据第12页内容提到的，EDR系统还会记录车辆发生碰撞事故的相关信息。具体的记录功能可能包括前方碰撞预警系统、紧急制动辅助系统、驾驶员状态监测系统等相关的操作和状态数据。然而，具体的EDR记录数据元素和说明，可以参考GB39732-2020《汽车事件数据记录系统》标准中的相关内容。综上，EDR系统捕捉的数据旨在帮助了解事故发生时车辆的状态，便于事故分析和提升车辆安全性。', 'reference': 'page_12', 'question_keywords': '事件数据记录系统 EDR Lynk&Co 领克汽车 记录信息\n', 'question_rewriting': '[1：Lynk&Co领克车型配备的EDR系统通常搜集哪些关键数据?,2：在Lynk&Co领克汽车中,EDR是如何记录事故相关的各项信息的?,3：领克Lynk&Co的汽车EDR系统主要包括哪些信息的记录功能?,4：请问对于Lynk&Co领克汽车,其EDR系统主要捕捉哪些操作和状态数据?]'}
# 6 {'question': '问题：事件数据记录系统（EDR）中的数据是否可以被黑客利用进行恶意攻击？', 'answer': '结合给定的资料，无法回答问题。资料中并没有提供关于事件数据记录系统（EDR）可能被黑客利用进行恶意攻击的信息。提供的资料主要涉及EDR系统的功能、数据采集及其在车辆维护和事故分析中的应用，并没有涉及安全性或潜在的风险。', 'reference': 'page_12', 'question_keywords': '事件数据记录系统 EDR 数据 黑客 利用 恶意攻击', 'question_rewriting': '[EDR系统里的信息是否存在被黑客用作不良目的的风险?,黑客能否操控事件数据记录系统（EDR）的数据以发起攻击?]'}
# 7 {'question': '问题：在国家环保法要求下，哪些情况下需要对车辆进行报废处理？', 'answer': '根据给定的资料，结合国家环保法的相关规定，以下情况下需要对车辆进行报废处理：\n\n1. 车辆达到使用年限。\n2. 车辆不能满足道路使用条件。\n\n资料中提到：“达到使用年限或不能满足道路使用条件的车辆应按国家环保法规要求进行报废处理。”\n\n至于哪些条件会导致车辆需要被强制报废，资料中并未直接提及具体的强制报废条件，但可以推断，除了上述的使用年限和道路使用条件外，可能还包括车辆存在严重的安全隐患、无法通过环保检测、车辆主要部件损坏无法修复等情况。\n\n因此，结合资料，第一个问题的答案为“达到使用年限或不能满足道路使用条件”，第二个问题则无法从资料中获得具体信息，但可以根据常规理解推断可能的原因。', 'reference': 'page_14', 'question_keywords': '国家环保法 车辆 报废处理', 'question_rewriting': '[1：根据国家环保法的规定,在哪些具体情况下必须对汽车进行淘汰处理?,2：依据国家环保法的规定,哪些条件会导致车辆需要被强制报废?]'}
# 8 {'question': '请问，如果车辆报废后，原车主是否还能使用该车辆的智能互联服务？', 'answer': '结合给定的资料，无法回答问题。资料中并未明确说明车辆报废后原车主是否可以继续使用车辆的智能互联服务。不过，根据第14页的内容，建议在车辆报废前联系Lynk&Co领克中心，咨询车辆报废相关事宜，这可能包括关于智能互联服务的处理。因此，对于这个问题，最好是直接咨询Lynk&Co领克中心获取官方信息。', 'reference': 'page_14', 'question_keywords': '车辆报废 原车主 智能互联服务', 'question_rewriting': '[1：当车辆报废,原车主是否仍然可以继续使用车辆的智能连接功能?\n2：车辆被报废后,原车主是否有权继续享受该车的智能互联服务?\n3：一旦车辆报废,原车主是否可以维持对车辆智能互联服务的使用?\n4：车辆报废后,原车主是否还能继续激活并使用该车辆的智能互联系统?]'}
# 9 {'question': '如何确保用车前的准备工作万无一失？', 'answer': '为确保用车前的准备工作万无一失，请遵循以下详细步骤：\n\n1. **驾驶前的准备**：\n   - 根据第53页的资料，开车前应正确调节驾驶员座椅，保证能够正常操作制动踏板和加速踏板，并且尽量将座椅位置靠后，确保乘坐舒适和操控方便。\n   - 使用位置记忆功能，将驾驶员座椅、外后视镜、抬头显示（HUD）调节并存储在理想位置。\n\n2. **中央显示屏设置**：\n   - 根据第271页和第273页的内容，通过中央显示屏的用户中心登录账户，并设置座椅位置记忆功能。\n   - 添加亲情账号并开启用车偏好自动同步，确保个人用车偏好能够在不同车辆间同步。\n\n3. **车辆状况检查**：\n   - 根据第17页的资料，用车前要检查轮胎胎压、剩余油量、剩余电量、可续航里程、车内温度和车辆位置等。\n   - 确保所有车灯和转向指示灯工作正常，轮胎压力处于正常范围，车窗玻璃干净清晰，驾驶员座椅、方向盘和后视镜调节至正确位置。\n\n4. **安全检查**：\n   - 检查仪表无警告灯点亮或故障警告信息。\n   - 确保无物品妨碍踏板行程，所有装运的物件已固定到位。\n\n5. **排放和节能驾驶**：\n   - 根据第164页内容，了解车辆满足的国Ⅵ排放标准，并在驾驶时采取节能措施，如平稳驾驶，避免急加速或急减速。\n\n6. **涉水驾驶和冬季驾驶准备**：\n   - 在涉水驾驶前，确定水深并清理不必要的重物，低速通过积水路段，并在涉水后尽快进行车辆检查。\n   - 冬季驾驶前，检查制动器、喇叭、转向助力和外部车灯是否正常工作。\n\n通过以上步骤，可以确保车辆使用前的所有准备工作都无误，做到万无一失。', 'reference': 'page_17', 'question_keywords': '用车前 准备工作 确保 万无一失', 'question_rewriting': '[如何保证开车前的一切准备工作都做到完美无缺?,怎样确保车辆使用前所需的所有准备工作都无误?]'}
# 10 {'question': '装载货物时，车内有哪些储物空间可以利用？', 'answer': '装载货物时，车内可以利用的储物空间包括：\n\n1. 前排储物空间：\n   - 遮阳板上的卡片/票据夹\n   - 无线充电板/置物板\n   - 手套箱\n   - 车门存储空间\n   - 眼镜盒\n   - 前副仪表台\n   - 前排中央扶手储物箱\n   - 前副仪表台侧网兜\n\n2. 第二排储物空间：\n   - 后排中央扶手和杯托\n   - 前排座椅靠背储物袋\n   - 车门储物空间\n   - 后扶手的杯托\n   - 衣帽钩（仅适用于轻量衣物）\n\n3. 后备厢储物空间：\n   - 后备厢侧网兜（注意不可放置过重物品）\n   - 折叠后排座椅靠背，扩大后备厢容积\n\n在装载货物时，有效利用这些储物区域的方法包括：\n- 将小件物品放入手套箱、车门存储空间、眼镜盒等区域。\n- 使用无线充电板/置物板存放手机等设备。\n- 将卡片/票据夹在遮阳板上。\n- 利用前排中央扶手储物箱和前副仪表台侧网兜存放零碎物品。\n- 在后排中央扶手和杯托、前排座椅靠背储物袋中存放小件物品。\n- 后备厢内放置大件或较重物品，注意平均分布和固定好货物。\n- 折叠后排座椅靠背以装载更多或较长的货物。\n\n在装载过程中，确保所有物品均被妥善固定，避免行车时发生位移。', 'reference': 'page_26', 'question_keywords': '装载 货物 车内 储物空间 利用', 'question_rewriting': '[1：在装运物品期间,我可以使用车内哪些储物区域?,2：在往车里装货时,应当如何有效利用车内的储物区域?,3：请问在装载过程中,车内哪些地方可以作为储物空间?,4：在进行货物装载,车内有哪些地方可以存放小件物品?]'}
# 11 {'question': '请问车辆手套箱的容量大小是多少？', 'answer': '结合给定的资料，无法回答问题。资料中并未提供关于车辆手套箱的具体容量大小的信息。手套箱的容量通常取决于车辆设计和制造商，而这些信息没有在给定的资料中提及。如果需要了解具体某款车型的手套箱容量，建议查阅该车型的官方手册或联系车辆制造商获取详细信息。', 'reference': 'page_28', 'question_keywords': '车辆 手套箱 容量 大小 是 多少？', 'question_rewriting': '[请问车辆的手套箱能装多少东西?,我想知道该车型的手套箱具体有多大容积?]'}
# 12 {'question': '如何合理安排前排的储物空间以提高实用性？', 'answer': '根据给定的资料，合理安排前排的储物空间以提高实用性的方法有以下几点：\n\n1. 使用遮阳板上的卡片/票据夹来存放卡片和票据，方便驾驶时快速取用。\n2. 利用无线充电板/置物板为手机等设备充电，同时可以放置一些小物品。\n3. 充分利用手套箱空间存放车辆文档、地图等。\n4. 合理使用车门存储空间，放置一些经常使用的物品。\n5. 利用眼镜盒存放眼镜，避免在驾驶时视线不清。\n6. 使用前副仪表台和前排中央扶手储物箱，存放小件物品，保持前排空间的整洁。\n7. 注意不要将尺寸不合适的容器卡入杯托，以免影响使用效果。\n\n通过上述方法，可以合理布局汽车前座的储物空间，使其更具功能性，从而提高前排空间的实用性。', 'reference': 'page_26', 'question_keywords': '合理安排 前排 储物空间 实用性 提高', 'question_rewriting': '[如何优化前排的储物布局来增强实用性?,怎样才能合理布局汽车前座的储物空间,使其更具功能性?]'}
# 13 {'question': '请问车辆手套箱的容量大小是多少？', 'answer': '结合给定的资料，无法回答问题。资料中并没有提供关于车辆手套箱的具体容量大小或容积信息。手套箱的大小可能因车型不同而有所差异，但所提供的资料并未涉及这方面的具体数据。', 'reference': 'page_28', 'question_keywords': '车辆 手套箱 容量 大小 是 多少？', 'question_rewriting': '[请问车辆的手套箱能装多少东西?,我想知道该车型的手套箱具体有多大容积?]'}
# 14 {'question': '如何正确使用前排座椅靠背储物袋？', 'answer': '根据给定的资料，正确使用前排座椅靠背储物袋的方法如下：\n\n在第26页的“装载货物第二排储物空间 使用后排中央扶手和杯托”部分提到：“前排座椅靠背储物袋。将扶手向前拉动并向下打开以使用。”这表明，在使用前排座椅靠背储物袋时，应先将扶手向前拉动，然后向下打开储物袋，以便放入或取出物品。\n\n此外，资料中还提到：“将松散物品装在密闭的储物空间内，确保物品被固定到位。”因此，在前排座椅靠背储物袋中存放物品时，应确保物品放置稳妥，避免因车辆行驶过程中的颠簸而导致物品滑落。\n\n综上所述，正确使用前排座椅靠背储物袋的方法是：先将扶手向前拉动并向下打开储物袋，然后将物品放入并确保物品固定好，以防行驶过程中物品滑落。', 'reference': 'page_26', 'question_keywords': '正确 使用 前排 座椅 靠背 储物袋', 'question_rewriting': '[怎样恰当利用前排座椅背部的储物口袋?,如何正确地在驾驶座和副驾驶座的靠背储物袋中存放物品?]'}
# 15 {'question': '请问，如果后排中央扶手和杯托被占用，驾驶员应该如何放置饮料？', 'answer': '根据给定的资料，如果后排中央扶手和杯托被占用，驾驶员可以考虑以下几种方式来放置饮料：\n\n1. 前排储物空间：可以使用前排的储物箱、副仪表台、遮阳板上的卡片/票据夹、手套箱、杯托等空间来放置饮料。\n\n2. 车门存储空间：前排车门通常也有一定的存储空间，可以用来放置饮料。\n\n3. 前排中央扶手储物箱：如果前排中央扶手下方有储物箱，也可以考虑用来放置饮料。\n\n需要注意的是，放置饮料时要确保容器尺寸适合，避免强行将尺寸不合适的容器卡入杯托，同时也要确保饮料容器固定好，防止在紧急制动时饮料被抛出。\n\n结合给定的资料，以上是驾驶员在后排中央扶手和杯托被占用时放置饮料的建议。', 'reference': 'page_26', 'question_keywords': '后排 中央扶手 杯托 驾驶员 饮料 放置', 'question_rewriting': '[请问在后排中央扶手和杯托不可用的情况下,驾驶员可以把饮料放在哪里?, 当后排的中央扶手和杯托已经被使用时,驾驶员有什么其他方式来放置他们的饮料吗?]'}
# 16 {'question': '如何通过手机验证码解锁手套箱？', 'answer': '根据给定的资料，如果您需要通过手机验证码来解锁手套箱，可以按照以下步骤操作：\n\n1. 当手套箱处于密码保护状态且已被锁定时，若您输入密码错误超过五次，系统会进入保护状态。\n2. 在保护状态中，2分钟后您可以通过手机验证码进行解锁。\n3. 您需要使用手机接收到的验证码，在相应的界面（可能是车辆的手机应用或者通过短信等方式）进行操作。\n4. 根据资料中的描述，可以通过中央显示屏进入“座舱体验”-“快捷设置”，然后点击启用/停用手套箱密码保护功能，这里可能会提供一个选项使用手机验证码解锁。\n5. 按照屏幕上的指示输入验证码，即可解锁手套箱。\n\n请注意，具体的操作步骤可能会根据车辆型号和系统的不同有所差异，上述步骤是基于给定资料的描述进行的一般性指导。如果在实际操作中遇到困难，建议咨询车辆的用户手册或者联系车辆制造商的客服进行协助。', 'reference': 'page_28', 'question_keywords': '手机验证码 解锁 手套箱', 'question_rewriting': '[如何使用手机接收的验证码来打开手套箱?,我用手机收到的验证码该怎么操作才能解开手套箱?]'}
# 17 {'question': '问题：如果手套箱被锁止了，但是忘记了密码，应该怎么办？', 'answer': '如果手套箱被锁止了，但是忘记了密码，您可以采取以下步骤：\n\n1. 尝试使用手套箱开关进行解锁。如果设置了密码，通常会有一个开关或按键，您可以按照提示操作，看是否有机会重新设置或跳过密码。\n\n2. 查阅车辆手册或相关说明，看是否有密码重置的方法。有些车辆可能允许通过特定的操作步骤来重置手套箱密码。\n\n3. 如果以上方法都不奏效，您可以通过中央显示屏进入“座舱体验”-“快捷设置”界面，尝试启用/停用手套箱密码保护功能。这可能需要您输入车主信息或通过其他方式验证身份。\n\n4. 如果车辆支持手机验证码解锁，可以尝试使用这一功能。\n\n5. 如果以上所有方法都无法解决问题，建议您联系最近的Lynk&Co领克中心，寻求专业的帮助。\n\n根据给定的资料，以上步骤是结合资料内容提出的建议。如果这些建议仍然无法帮助您解决问题，那么您可能需要联系专业的维修服务进行进一步的帮助。', 'reference': 'page_28', 'question_keywords': '手套箱 锁止 忘记 密码 怎么办', 'question_rewriting': '[1：当手套箱处于锁定状态而我记不起密码时,我该如何处理这一情况?,2：如果手套箱上锁了而我遗忘了解锁密码,有哪些解决方法?,3：我手套箱的锁定了,但密码记不起来了,能给我一些建议吗?,4：面对手套箱锁定且密码遗忘的状况,我应该采取哪些步骤?]'}
# 18 {'question': '如何确保尾门在自动打开或关闭过程中安全停止？', 'answer': '为确保尾门在自动打开或关闭过程中的安全停止，以下是一些操作指南：\n\n1. 在尾门自动打开/关闭前，应确保尾门运动范围内无其他人员或障碍物存在，以避免撞击或夹伤。\n\n2. 如果在尾门自动打开或关闭过程中需要立即停止，可以短按尾门下部的关闭按键或仪表板上的尾门解锁按钮，使尾门停止运动。\n\n3. 如果尾门在关闭过程中触碰到障碍物，车辆会自动停止尾门关闭动作，并伴有长鸣音提醒。\n\n4. 车辆静止时，如果尾门在关闭过程中触碰到障碍物，尾门将停止关闭并打开至设置的开启位置，并伴有长鸣音。\n\n5. 在操作尾门时，切勿以任何形式妨碍尾门动作，以免影响尾门正常启闭。\n\n6. 若需要在低矮场景下使用尾门，可以通过设置电动尾门的开启角度来确保安全。\n\n遵循以上操作指南，可以确保尾门在自动打开或关闭过程中的安全停止。', 'reference': 'page_30', 'question_keywords': '确保 尾门 自动 打开 关闭 过程 安全 停止', 'question_rewriting': '[如何保证在自动启闭过程中尾门能够安全地中断动作?,怎样确保自动开合的尾门在过程中可以安全地暂停?]'}
# 19 {'question': '尾门自动打开/关闭的机制是如何感应障碍物的？', 'answer': '尾门自动打开/关闭的机制是通过内置的传感器来感应障碍物的。具体来说，在尾门的运动过程中，如果触碰到障碍物，车辆会通过这些传感器检测到这一情况，并立即停止尾门的动作。根据第34页的内容，如果尾门在关闭过程中触碰到障碍物，尾门将停止关闭并保持在当前位置，同时伴有长鸣音；如果是在打开过程中触碰到障碍物，尾门将停止打开并保持在当前位置，同样伴有长鸣音。这说明尾门的防夹保护机制是通过物理接触感应来实现的，以保护人员和物品安全。至于具体的感应原理，资料中并未明确说明，但通常这类系统会使用接近传感器、压力传感器或类似的装置来检测尾门与障碍物之间的接触或距离变化。', 'reference': 'page_30', 'question_keywords': '尾门 自动打开/关闭 感应 障碍物 机制\n', 'question_rewriting': '[尾门在自动开闭过程中,是通过什么方式检测到障碍物的?, 尾门实现自动开合时,其检测障碍物的原理是怎样的?]'}
# 20 {'question': '如何确保尾门在关闭时安全可靠？', 'answer': '为确保尾门在关闭时的安全性和可靠性，可以遵循以下步骤和注意事项：\n\n1. 确保尾门运动范围内无其他人员或障碍物存在。在尾门开始关闭之前，检查周围环境，避免因为障碍物导致尾门关闭受阻。\n\n2. 使用电动尾门下边缘的关闭按键轻按关闭尾门，电动尾门将自动吸紧关闭。\n\n3. 车辆静止时，如果尾门在关闭过程中触碰到障碍物，尾门将停止关闭并打开至设置的开启位置，并伴有长鸣音，这是防夹保护功能的作用。\n\n4. 在中央显示屏中，进入“车辆设置”下的“电动尾门”界面，可以设置电动尾门的开启角度，以便在低矮的空间中使用。\n\n5. 如果遇到尾门自动打开/关闭功能异常，可以通过启动车辆来重新激活该功能。\n\n6. 注意不要在短时间内多次打开/关闭尾门，因为这样可能导致自动打开/关闭功能暂时停用。\n\n7. 如果中控锁锁止时解锁尾门后，45秒内未打开尾门，尾门将自动重新锁止。\n\n8. 当操作尾门时，切勿使用身体任何部位或其他物品测试尾门防夹或防撞保护功能。\n\n9. 在有信号干扰的地方，例如充电桩、大型停车场、变电站等，智能钥匙可能会受到干扰，导致尾门解锁功能异常，此时请使用其他方式或排除干扰后再尝试。\n\n通过上述步骤和注意事项，可以确保尾门在关闭时的安全性和可靠性。', 'reference': 'page_34', 'question_keywords': '确保 尾门 关闭 安全 可靠', 'question_rewriting': '[如何保证尾门关闭时的安全性?,怎样让尾门在关闭时更加稳固可信?]'}
# 21 {'question': '尾门在关闭过程中如果遇到障碍物会怎样反应？', 'answer': '尾门在关闭过程中如果遇到障碍物，会停止关闭并保持在当前位置。同时，车辆会伴有长鸣音提示。如果车辆在运动过程中尾门触碰到障碍物，尾门将停止关闭并保持在当前位置；如果车辆静止，尾门将打开至设置的开启位置。这是尾门防夹保护功能的一部分，用以避免对障碍物或人员造成伤害。', 'reference': 'page_34', 'question_keywords': '尾门 关闭 障碍物 反应', 'question_rewriting': '[尾门在关闭时碰到了障碍物会发生什么情况?,当尾门在关闭时检测到有物体挡住,它会有何动作?]'}
# 22 {'question': '如何确保电动尾门在运动过程中不会伤及人员或障碍物？', 'answer': '为确保电动尾门在运动过程中不会伤及人员或障碍物，可以采取以下措施：\n\n1. 在操作电动尾门之前，确保尾门运动范围内无其他人员或障碍物存在。\n   \n2. 使用尾门解锁按钮或Lynk&CoApp控制尾门时，应注意周围环境，避免在有人或有障碍物的情况下操作。\n\n3. 遵循用户手册中的警告，操作尾门时切勿以任何形式妨碍尾门动作。\n\n4. 若使用感应式电动尾门，当转向灯缓慢闪烁时，后退一小步，待转向灯快速闪烁后，尾门将自动打开。在此过程中，应确保不离开车辆感应区域。\n\n5. 在可能存在信号干扰的地方（如充电桩、大型停车场、变电站等），避免使用智能钥匙操作电动尾门，以防功能异常。\n\n6. 若短时间内多次打开/关闭尾门，电动尾门的自动打开/关闭功能可能会暂时停用，此时应等待一段时间后再尝试使用。\n\n7. 在雨雪天气或光线强烈的环境下，注意泊车辅助传感器和摄像头可能受到的影响，谨慎使用电动尾门。\n\n8. 若电动尾门在关闭过程中触碰到障碍物，尾门将停止关闭并保持在当前位置，此时应及时清除障碍物。\n\n通过以上措施，可以有效避免电动尾门在开启或关闭过程中对人员或障碍物造成伤害。', 'reference': 'page_30', 'question_keywords': '电动尾门 运动过程 伤及人员 障碍物', 'question_rewriting': '[如何避免电动尾门在开启或关闭时对人员或障碍物造成伤害?, 电动尾门在操作时怎样保证不会碰撞到人或物体?]'}
# 23 {'question': '问题：如果尾门在关闭过程中触碰到障碍物，那么尾门会自动关闭到哪个位置？', 'answer': '如果尾门在关闭过程中触碰到障碍物，那么尾门会停止关闭并保持在当前位置，同时伴有长鸣音。车辆静止时，尾门会停止关闭并打开至设置的开启位置，同时伴有长鸣音。因此，尾门不会自动关闭到一个特定的位置，而是停止在碰到障碍物时的位置，或者打开至预设的开启位置。', 'reference': 'page_34', 'question_keywords': '尾门 关闭 过程中 触碰 障碍物 自动关闭 位置', 'question_rewriting': '[1：尾门在关闭时遇到阻碍会停止在哪个特定的位置?\n2：尾门遭遇障碍物后自动回弹至何处?\n3：当尾门接触到关闭过程中的障碍,它会回到什么样的位置?\n4：尾门碰到东西后,自动闭合至哪个点?]'}
# 24 {'question': '如何确保在装载货物时汽车的安全性？', 'answer': '在装载货物时，为确保汽车的安全性，以下措施是必要的：\n\n1. **尾门防夹保护**：通过中央显示屏设置电动尾门，确保在关闭尾门时，如果触碰到障碍物，尾门能够停止关闭并伴有长鸣音提示，以避免夹伤或损坏。\n\n2. **检查尾门运动范围**：在操作尾门之前，确认尾门运动范围内没有其他人员或障碍物。\n\n3. **使用合适的固定带**：装载货物时，严禁使用不合适或损坏的固定带，以防紧急刹车或发生事故时，货物抛起。\n\n4. **禁止超载**：车顶行李架和后备厢内装载的货物不得超过规定的最大载荷和质量限制。\n\n5. **合理分布载荷**：车顶行李架上的货物应平均分布，并将最重的物品放在底部，以降低车辆重心，保证车辆操纵和转向的稳定性。\n\n6. **固定货物**：确保后备厢内的货物固定好，以防紧急制动时货物移动。\n\n7. **使用遮物帘**：使用遮物帘遮盖后备厢内物品，不仅可以防止物品在事故中被抛出，还能避免物品伤害车内人员。\n\n8. **注意货物形状**：用柔软的材料包住货物的尖利边角，避免在紧急情况下造成伤害。\n\n9. **装卸货物时的车辆状态**：装卸较长或较大货物时，应将挡位切换至驻车挡（P），并关闭发动机，以防车辆意外移动。\n\n通过以上措施，可以有效确保在装载货物时汽车的安全性。', 'reference': 'page_21', 'question_keywords': '确保 装载 货物 汽车 安全性', 'question_rewriting': '[如何保证在装货过程中车辆的安全?,怎样确保在汽车装载物品时的安全措施?]'}
# 25 {'question': '请问这辆正在装载货物的汽车最多可以装载多少立方米的货物？', 'answer': '结合给定的资料，无法回答问题。资料中并没有提供有关汽车最大货物体积或装载容积的具体立方米数据。', 'reference': 'page_21', 'question_keywords': '装载 货物 汽车 最多 立方米 货物', 'question_rewriting': '[请问这辆汽车在装载时能够承载的最大货物体积是多少立方米?, 这款汽车的最大货物装载容积是多少立方米?]'}
# 26 {'question': '如何设置遥控钥匙的靠近解锁远离上锁功能？', 'answer': '要设置遥控钥匙的靠近解锁远离上锁功能，您需要在中央显示屏中进行以下操作：\n\n1. 点击“车辆设置”选项。\n2. 选择“门锁”进入门锁设置界面。\n3. 在门锁设置界面中找到并点击“开启/关闭靠近解锁远离上锁功能”选项。\n\n通过上述步骤，您就可以激活或调整遥控钥匙的靠近解锁和远离上锁功能。根据您的车辆设定，这个功能可能会在特定条件下自动关闭，如车辆处于信号干扰的环境中或长时间未使用车辆。在这种情况下，您可能需要使用遥控钥匙按键、无钥匙进入系统或机械钥匙等其他方式解锁车门，并重新激活该功能。此外，如果功能出现异常，建议排除干扰后再次尝试或联系Lynk&Co领克中心寻求帮助。', 'reference': 'page_40', 'question_keywords': '设置 遥控钥匙 靠近解锁 远离上锁 功能', 'question_rewriting': '[怎样才能激活遥控钥匙的接近解锁和远离锁定功能?,如何调整遥控钥匙实现近距离自动解锁和远离自动上锁?]'}
# 27 {'question': '如何确保遥控钥匙的操作不受干扰？', 'answer': '为确保遥控钥匙的操作不受干扰，以下是一些可以采取的措施：\n\n1. 避免将遥控钥匙与手机、发射机、无线电广播设备等无线装置放在一起，以防互相干扰。\n2. 在使用遥控钥匙时，避免将其接触金属材料或被金属材料覆盖。\n3. 避免将遥控钥匙放置在靠近计算机、手机、无线鼠标等可能产生干扰的设备附近。\n4. 确保遥控钥匙的电量充足，低电量可能导致遥控钥匙功能受限。\n5. 在遥控钥匙功能受影响而失效时，可以使用无钥匙进入系统或机械钥匙等其他方式解锁/闭锁车辆。\n6. 如果车辆位置靠近无线电塔/电视塔或发电站等可能存在无线干扰的环境，请尝试更换位置后再操作遥控钥匙。\n7. 当遥控钥匙受到信号干扰时，可以尝试按住车门把手外部传感器区域，关闭所有车窗和全景天窗，然后再次触摸外部传感器，使所有车窗和全景天窗关闭动作停止，以便进行操作。\n\n通过以上措施，可以降低遥控钥匙受到外界干扰的可能性，确保其正常使用。', 'reference': 'page_42', 'question_keywords': '确保 遥控钥匙 操作 不受干扰', 'question_rewriting': '[如何保证远程钥匙的控制不会受到外界影响?,怎样确保无线车钥匙的使用不会被信号干扰?]'}
# 28 {'question': '如何通过触摸车门外把手上车内解锁和闭锁的外部感应区域来操作车辆的闭锁？', 'answer': '通过触摸车门外把手上的车内解锁和闭锁的外部感应区域来操作车辆的闭锁，操作步骤如下：\n\n1. 确保所有车门都已关闭。\n2. 携带遥控钥匙或蓝牙钥匙。\n3. 触摸前门外把手上的外部感应区域。\n4. 车辆将自动闭锁。\n\n此外，如果设置为单门解锁模式，触摸前门外把手上的内部传感器区域仅会解锁当前车门；如果设置为全车解锁模式，触摸该区域会解锁全车车门。\n\n需要注意的是，如果遥控钥匙或蓝牙钥匙受到信号干扰，无钥匙进入系统可能会功能异常。在这种情况下，可以使用遥控钥匙按键、无钥匙进入系统或机械钥匙等其他方式解锁/闭锁车辆。', 'reference': 'page_44', 'question_keywords': '触摸 车门 把手 解锁 闭锁 外部感应区域 操作 车辆 闭锁', 'question_rewriting': '[如何使用车门外把手的感应区域来进行车辆的锁定和解锁操作?, \n 如何借助车门外把手的感应部分来实现车辆的锁定与解锁功能?]'}
# 29 {'question': '问题：如果遥控钥匙/蓝牙钥匙丢失或损坏，车辆如何进行闭锁和解锁操作？', 'answer': '如果遥控钥匙或蓝牙钥匙丢失或损坏，您仍然可以通过以下方式对车辆进行闭锁和解锁操作：\n\n1. 使用机械钥匙：大多数遥控钥匙都包含一个可以手动插入车锁的机械钥匙。如果遥控或蓝牙功能失效，您可以取出机械钥匙，手动解锁和锁闭车门。\n\n2. 无钥匙进入系统：如果车辆配备了无钥匙进入系统，在遥控钥匙/蓝牙钥匙丢失或损坏的情况下，您仍然可以通过触摸前门外把手上的传感器区域来解锁和闭锁车辆。\n\n3. Lynk&Co App：如果您的车辆与Lynk&Co App绑定成功，即使遥控钥匙或蓝牙钥匙出现问题，也可以使用该App来解锁和闭锁车门。\n\n4. 额外的遥控钥匙：如果您有备用遥控钥匙，可以直接使用它来进行车辆的解锁和闭锁操作。\n\n5. 联系领克中心：如果所有遥控钥匙都丢失或损坏，您可以联系Lynk&Co领克中心，获取一把已编程的新遥控钥匙。\n\n请注意，如果钥匙丢失，为了保证车辆安全，建议尽快到领克中心重新编程所有剩余的遥控钥匙，以防止丢失的钥匙被他人用于非法解锁车辆。', 'reference': 'page_42', 'question_keywords': '遥控钥匙 蓝牙钥匙 丢失 损坏 闭锁 解锁 操作', 'question_rewriting': '[如果我的车钥匙（遥控或蓝牙）不见了或者不能用了,该怎么锁车和开锁?,当遥控钥匙或蓝牙钥匙不复存在或出现故障时,车辆锁闭与解锁的操作应如何进行?]'}
# 30 {'question': '如何确保车辆在低速行驶或静止时，乘客安全地使用开门预警系统？', 'answer': '确保车辆在低速行驶或静止时，乘客能够安全使用开门预警系统的步骤如下：\n\n1. 确保开门预警系统已开启。在中央显示屏中点击“LynkCo-Pilot”-“驾驶安全监测”，找到并开启开门预警系统。\n\n2. 提醒乘客在车辆慢速行驶或静止时，也要遵循开门预警系统的指示。当系统检测到相邻两侧后方的交通状况存在潜在的碰撞风险时，外后视镜指示灯及车内氛围灯会开始闪烁并发出声音警告。\n\n3. 告知乘客在收到开门预警系统的警告时，不要立即打开车门。应该等待直到系统确认无碰撞风险，指示灯和声音警告停止。\n\n4. 教育乘客识别开门预警系统的局限性，例如在恶劣天气、车道宽度变化、或针对较小、静止或快速移动的目标时，系统可能无法正常工作。\n\n5. 如果乘客不确定情况，应鼓励他们询问驾驶员或使用车内外后视镜手动检查后方情况，确保安全后再开门。\n\n6. 确保车辆的其他安全功能，如后方碰撞预警系统，也是开启状态，以提供额外的安全保护。\n\n遵循以上步骤，可以在车辆低速行驶或静止时，帮助乘客安全有效地使用车门开启预警功能，减少因开门导致的碰撞风险。', 'reference': 'page_46', 'question_keywords': '车辆 低速行驶 静止 乘客 安全 开门 预警系统', 'question_rewriting': '[如何保证在车辆慢速行驶或停止状态下,乘客可以利用开门预警系统而安全无忧?, 在低速或停车状态下,怎样让乘客安全有效地使用车门开启预警功能?]'}
# 31 {'question': '问题：主驾座椅迎宾功能在哪些情况下会自动停用？', 'answer': '主驾座椅迎宾功能在以下特定条件下会自动停用：若驾驶员将座椅位置调整得很靠后时，该功能将自动停用。资料中没有提供其他自动失效的情况，因此，根据给定的资料，这是唯一提到的自动停用场景。', 'reference': 'page_46', 'question_keywords': '主驾座椅 迎宾功能 自动停用情况下', 'question_rewriting': '[1：在什么特定条件下,驾驶座迎宾功能会自行关闭?,2：哪些情况下,车辆的主驾驶位迎宾功能会自动失效?,3：我想了解主驾驶座椅的迎宾功能在哪些自动禁用的场景中?,4：能告诉我哪些时候主驾位的迎宾功能会停止工作吗?]'}
# 32 {'question': '如何确保车辆的防盗系统正常工作？', 'answer': '为确保车辆的防盗系统正常工作，您可以遵循以下步骤：\n\n1. 定期检查：确保车辆所有门窗关闭并锁好，这有助于防盗系统进入完全的戒备状态。\n   \n2. 防盗系统测试：通过以下方式检测并确认防盗系统是否运行正常：\n   - 使用遥控钥匙或Lynk&Co App尝试锁定和解锁车辆，确认系统是否响应正常。\n   - 观察车辆在锁止10秒后是否进入戒备状态，可以通过轻微拉门把手等方式检查是否有警报响起。\n\n3. 确认系统警告：如果仪表上出现任何关于防盗系统的警告信息，如“DOW故障”等，应立即联系Lynk&Co领克中心进行检查。\n\n4. 检查钥匙和App连接：确认遥控钥匙或Lynk&Co App中的蓝牙钥匙在车辆的有效检测范围内，并能够正确启动车辆。\n\n5. 使用Lynk&Co App：定期通过Lynk&Co App检查车辆状态，确保防盗系统没有被远程激活。\n\n6. 注意系统更新：如果有系统更新提示，应及时更新车辆的防盗系统软件，以保证系统功能的最新和最佳状态。\n\n通过上述方法，可以有效地检测并确认车辆防盗系统的运行状态，确保其正常工作。如果发现任何问题，应及时联系专业的领克服务中心进行维修和检查。', 'reference': 'page_48', 'question_keywords': '确保 车辆 防盗系统 正常 工作', 'question_rewriting': '[怎样才能保证汽车防盗系统运作无误?,如何检测并确认车辆防盗系统运行正常?]'}
# 33 {'question': '在驾驶前，应如何正确调节驾驶员座椅以确保安全和舒适？', 'answer': '在驾驶前，为了确保安全和舒适，应按照以下步骤正确调节驾驶员座椅：\n\n1. 确保车辆处于静止状态，避免在行驶过程中调节座椅。\n2. 调节座椅高度，使您的眼睛与车外路面保持水平，这样可以获得最佳的视野。\n3. 调整座椅前后位置，确保能够舒适地伸直双腿，同时膝盖略微弯曲，可以正常操作制动踏板和加速踏板。\n4. 调整座椅靠背角度，保持背部自然贴合座椅，尽量坐直，以保证在驾驶过程中有良好的支撑。\n5. 对于孕妇，应先咨询医生是否能够驾驶车辆，调节座椅使腹部远离方向盘，并确保安全带正确绕过肩部和胸部，腰部安全带紧贴在隆起的腹部以下。\n6. 使用座椅位置记忆功能（如有配备），在开车前将座椅、外后视镜和抬头显示（HUD）调节到合适的位置，并存储设置。\n\n通过中央显示屏可以进行以下操作：\n- 进入座椅设置界面，选择驾驶员座椅。\n- 点击需要调节的功能按键，如靠背角度或座椅位置，根据指示箭头进行微调。\n- 调节座椅加热功能（如有配备），以提高乘坐舒适度。\n\n最后，确保所有调整不会干扰颈椎保护系统的功能，例如，不要让座椅靠背与折叠的后排座椅靠背接触。\n\n遵循这些步骤，可以在驾驶前正确调节驾驶员座椅，既保证了安全，又确保了乘坐的舒适度。', 'reference': 'page_52', 'question_keywords': '驾驶前 正确调节 驾驶员座椅 安全 舒适', 'question_rewriting': '[怎样才能正确调整驾驶座椅以同时达到安全和舒适的目的?,在开车前,有哪些步骤可以正确地进行驾驶员座椅的调整以保障安全与舒适度?]'}
# 34 {'question': '问题：如何在不调节驾驶员座椅的情况下确保能正常操作制动踏板和加速踏板？', 'answer': '确保在不调节驾驶员座椅的情况下能正常操作制动踏板和加速踏板，首先应在开车前正确调节驾驶员座椅。根据资料，需要确保座椅位置能够在保证乘坐舒适和操控方便的前提下尽量靠后，以便能正常操作制动踏板和加速踏板。\n\n具体来说，可以通过以下方式来保证：\n\n1. 在车辆静止时，调整座椅的位置、高度、角度，确保双脚能自然地放在制动踏板和加速踏板上，膝盖略微弯曲，脚跟能稳固地贴合地面。\n\n2. 使用座椅的位置记忆功能，存储适合自己操作的座椅、外后视镜和抬头显示（HUD）的位置。这样，每次进入车内后，可以通过点击中央显示屏上的“座舱体验-座椅”界面，快速恢复到之前设置好的位置。\n\n3. 在行驶过程中，遵守资料中的警告，不调节驾驶员座椅，以免影响正常操作制动踏板和加速踏板。\n\n通过以上步骤，可以在不调节驾驶员座椅的情况下，依然有效控制制动和加速踏板。', 'reference': 'page_52', 'question_keywords': '制动踏板 加速踏板 正常操作 不调节 驾驶员座椅 确保', 'question_rewriting': '[如何保证在不动驾驶员座位的情况下仍能方便地使用刹车和油门踏板?, 怎样才能在不移动驾驶座的情况下,依然能够有效控制制动和加速踏板?]'}
# 35 {'question': '如何正确使用座椅位置记忆功能？', 'answer': '正确使用座椅位置记忆功能的方法如下：\n\n1. 首先，将驾驶员座椅、外后视镜（如有抬头显示HUD，也需调节至适当位置）调整到您希望记忆的位置。\n   \n2. 然后，在中央显示屏中选择“座舱体验-座椅”进入座椅设置界面。\n\n3. 在座椅设置界面中选择“驾驶员座椅”，并点击需要调节的座椅功能按键。\n\n4. 对座椅位置、靠背角度、座垫角度等调整到满意状态后，选择“位置一”、“位置二”或“位置三”按键，以保存您当前的座椅和外后视镜（以及HUD）位置。\n\n5. 点击“保存”按键，此时系统会存储您的座椅位置记忆。\n\n6. 当需要恢复到已保存的记忆位置时，在座椅设置界面中选择相应的记忆位置（“位置一”、“位置二”或“位置三”），并点击“恢复”按键。\n\n注意事项：\n- 车辆行驶时，请勿使用座椅位置记忆功能。\n- 在座椅自动移动的过程中，若您手动调节了座椅位置，座椅将停止移动。\n- 请勿阻碍座椅移动，否则可能导致座椅损坏。\n\n遵循以上步骤和注意事项，即可正确设置并使用汽车座椅的位置记忆功能。', 'reference': 'page_54', 'question_keywords': '座椅位置记忆功能 使用 方法', 'question_rewriting': '[怎样恰当操作汽车座椅的记忆功能?,如何正确设置并使用车座的记忆位置?]'}
# 36 {'question': '问题：如果座椅在自动移动过程中被手动调节，那么座椅会怎样移动？', 'answer': '如果座椅在自动移动过程中被手动调节，根据第54页的说明，座椅将停止移动。这意味着手动调节会打断座椅的自动调整流程，导致座椅不再继续按照预设的程序进行移动。座椅的位置会保持在手动调节那一刻的状态。', 'reference': 'page_54', 'question_keywords': '座椅 自动移动 手动调节 移动\n', 'question_rewriting': '[如果我在座椅自动调整时手动干预,会发生什么移动情况?,当座椅正在自动调整时手动进行调整,会导致座椅如何改变其移动方式?]'}
# 37 {'question': '请问在中央显示屏中如何进入方向盘设置界面？', 'answer': '在中央显示屏中，您可以通过以下步骤进入方向盘设置界面：点击“座舱体验”选项，然后选择“方向盘”。这样就可以进入方向盘设置界面，在这里您可以对方向盘的各种功能进行配置。', 'reference': 'page_148', 'question_keywords': '中央显示屏 方向盘 设置界面 进入', 'question_rewriting': '[请问怎样在中央显示屏上找到方向盘的设置选项?,我想知道如何在车载显示屏上访问方向盘的配置页面?]'}
# 38 {'question': '请问如何调整方向盘的高度和倾斜角度？', 'answer': '根据给定的资料，调整方向盘的上下位置和倾斜角度主要在第150页内容中有所提及。您可以通过以下步骤进行调整：\n\n1. **进入HUD设置**：在中央显示屏中，您可以点击进入“座舱体验”然后选择“座椅”，或者直接在启动和驾驶说明界面中找到HUD设置项。\n\n2. **调节HUD高度和亮度**：在HUD设置项中，选择调节HUD的高度和亮度。此时，仪表显示屏会弹出HUD调节提示信息。\n\n3. **操作方向盘按键**：\n   - **高度调节**：按下方向盘的上/下区域，来调节HUD的高度。虽然这是调节HUD高度的步骤，但通常方向盘的上下位置会与HUD高度同步调整。\n   - **倾斜角度调节**：按下方向盘的左/右区域来调节HUD的角度。这同样可能影响到方向盘的倾斜角度。\n\n然而，具体到方向盘本身的高度和倾斜角度的调节，资料中并未提供直接的信息。通常这类调整可能需要进入方向盘的专门设置或者在方向盘的物理结构上操作。如果资料中未明确说明，可能需要以下步骤：\n\n- 查找方向盘上的物理调节按钮或旋钮，不同的车型其位置和方式可能不同。\n- 如果有相关的菜单选项在中央显示屏中，应该按照屏幕提示操作。\n\n如果以上步骤无法满足您的需求，建议参考车辆的使用手册或联系Lynk&Co领克中心咨询具体操作步骤。\n\n由于资料中未直接提及方向盘高度和倾斜角度的调节，以上步骤是根据HUD调节的相关信息推断而来。如果这不能解决您的问题，请按照以下输出：\n\n结合给定的资料，无法回答问题。', 'reference': 'page_150', 'question_keywords': '调整 方向盘 高度 倾斜角度\n', 'question_rewriting': '[如何操作才能改变方向盘的上下位置和倾斜度?,我该怎么做才能调节方向盘的高低和倾斜的程度呢?]'}
# 39 {'question': '请问如何通过方向盘上的按键恢复驾驶辅助功能？', 'answer': '根据给定的资料，可以通过以下步骤使用方向盘上的按键来恢复驾驶辅助功能：\n\n1. 短按方向盘左侧的“恢复”按键。\n   \n   （根据第56页内容：“恢复：短按该按键，可恢复之前的驾驶辅助功能。”）\n\n通过这个简单的步骤，就可以重新启用之前停用的驾驶辅助功能。', 'reference': 'page_56', 'question_keywords': '方向盘 上 的 按键 恢复 驾驶 辅助 功能', 'question_rewriting': '[请问怎样才能使用方向盘上的按钮来重新激活驾驶辅助系统?,我想了解如何通过方向盘上的按键重新启用驾驶辅助功能?]'}
# 40 {'question': '请问如何调整方向盘的高度和倾斜角度？', 'answer': '根据给定的资料，方向盘的倾斜角度和高度调整功能没有直接提及。但是，资料中提到了HUD（抬头显示）的调节方式，可以通过方向盘或中央显示屏进行角度和亮度的调节。对于方向盘本身的调整，资料没有给出具体操作步骤。\n\n因此，结合给定的资料，无法回答关于如何调整方向盘的高度和倾斜角度的问题。如果需要了解这方面的信息，建议查阅车辆的用户手册或联系专业的汽车服务中心获取详细指导。', 'reference': 'page_150', 'question_keywords': '方向盘 高度 倾斜角度 调整', 'question_rewriting': '[请问如何设置方向盘的上下位置和倾斜度?,我想知道怎样改变方向盘的垂直高度和水平倾斜角度?]'}
# 41 {'question': '在驾驶前调整方向盘时，需要注意哪项安全警告？', 'answer': '在驾驶前调整方向盘时，需要注意的安全警告包括：\n\n- 根据第59页的说明，当组合仪表显示车门/安全带提醒界面时，必须先按下方向盘右侧确认按键后，才能操作方向盘调整功能，以确保安全。\n- 调整方向盘时，需要先向下推锁定杆以便松开方向盘，调整到适合的位置后再向上推锁定杆，将方向盘锁止到位，并在调整完毕后确保方向盘已牢牢锁止（第59页）。\n- 警告中提到，在车辆行驶时，请勿使用驾驶员位置记忆功能调整方向盘位置（第55页）。\n\n这些都是在驾驶前调整方向盘时应遵守的安全规定和注意事项。', 'reference': 'page_59', 'question_keywords': '驾驶前 调整 方向盘 安全警告', 'question_rewriting': '[1：在开车前,调整方向盘时应留意哪些安全提示?\n2：在进行方向盘调节前,有哪些重要的安全注意事项?\n3：在启动车辆前调整方向盘位置时,需要遵守哪些安全规定?\n4：关于方向盘的调整,在驾驶之前有哪些安全警示需要考虑?]'}
# 42 {'question': '在转向柱未牢固锁止的情况下驾车可能会导致什么后果？', 'answer': '在转向柱未牢固锁止的情况下驾车可能会导致方向盘意外偏移，使驾驶员失去对车辆的控制，从而增加危险驾驶和事故发生的风险。这种情况有可能导致严重的交通事故，对驾驶员和乘客的安全构成威胁，并可能对其他道路使用者造成危害。因此，只有在车辆停止且转向柱牢固锁定的情况下，才能开始行驶。', 'reference': 'page_60', 'question_keywords': '转向柱 未牢固锁止 驾车 后果', 'question_rewriting': '[1：如果驾驶时转向柱没有正确固定,可能会引发哪些问题?,2：在转向柱没有锁定稳妥的情况下继续行驶,会有什么样的潜在风险?]'}
# 43 {'question': '问题：在什么情况下，胎压监测系统会开始闪烁，并伴有声音报警？', 'answer': '在以下特定情境下，胎压监测系统会启动闪烁和响铃警告：\n\n1. 当轮胎温度高时。\n2. 当轮胎漏气时。\n3. 当传感器电量低时。\n4. 胎压低报警被激活时。\n\n在这些条件下，轮胎气压监控系统会显示闪烁并发出警报声：\n\n1. 对应报警轮胎开始闪烁，并伴有声音报警。\n2. 仪表显示屏会弹出提示信息。\n3. 当胎压低报警被激活时，胎压监测系统状态指示灯会持续点亮直到报警消除。\n\n请注意，还有一些其他因素可能导致D-TPMS（主动式胎压监测系统）工作异常，但不在您询问的直接范围内。', 'reference': 'page_62', 'question_keywords': '胎压监测系统 开始闪烁 伴有声音报警 情况下\n', 'question_rewriting': '[胎压监测系统在哪些特定情境下会启动闪烁和响铃警告?, 在哪些条件下,轮胎气压监控系统会显示闪烁并发出警报声?]'}
# 44 {'question': '问题：如果车辆在行驶过程中突然出现轮胎漏气，驾驶员应该采取哪些紧急措施以确保安全？', 'answer': '如果车辆在行驶过程中突然出现轮胎漏气，驾驶员应立即采取以下紧急措施以确保安全：\n\n1. 稳定情绪，保持冷静。\n2. 紧握方向盘，保持车辆稳定，避免剧烈转向。\n3. 缓慢减速，避免急刹车，以免因轮胎压力不均导致车辆失控。\n4. 将车辆驶向最近的应急车道或安全区域停车。\n5. 打开危险报警闪光灯，以提醒其他车辆注意。\n6. 检查漏气的轮胎，如果条件允许，可以使用车辆配备的补胎套装进行紧急修补。\n   - 依据第342页内容，按照补胎套装使用说明进行操作，注意补胎液只适用于轮胎胎面上的穿孔。\n   - 使用电动充气泵将轮胎充气至推荐的胎压规格。\n7. 如果无法修补，更换备用轮胎。\n8. 在补胎或更换轮胎后，以不超过80km/h的速度平稳行驶，并尽快找到Lynk&Co领克中心进行专业检查和维修。\n9. 如果车辆无法继续行驶，呼叫紧急道路救援服务。\n\n请驾驶员时刻注意，安全是最重要的，任何紧急措施的实施都应以确保自身及乘客安全为前提。', 'reference': 'page_342', 'question_keywords': '轮胎漏气 驾驶员 紧急措施 安全', 'question_rewriting': '[1：在驾车时若遇到轮胎突然漏气的情况,驾驶员应当如何进行紧急处理以保证行驶安全?,2：当车辆在行进中意外发生轮胎漏气,驾驶者应采取哪些紧急措施来保障自身及乘客的安全?,3：碰到轮胎在行驶途中突然开始漏气,驾驶员需要实施哪些应急措施才能确保行车安全?]'}
# 45 {'question': '如何正确使用自动雨刷？', 'answer': '正确使用自动雨刷的方法如下：\n\n1. 在使用雨刮前，请先清除挡风玻璃上的冰和积雪，并确认雨刮片没有冻结在挡风玻璃上。\n2. 当挡风玻璃上有尘沙、鸟粪、昆虫、树浆等异物时，请先清洁挡风玻璃，以免损坏雨刮片或影响清洁效果。\n3. 避免在挡风玻璃干燥的情况下开启雨刮，以免导致雨刮片和挡风玻璃损坏。\n4. 定期清洁和检查雨刮片，以延长其使用寿命。\n5. 使用合格的洗涤液，避免使用不合格的洗涤液导致洗涤器损坏。\n\n对于雨量感应式自动雨刷：\n\n1. 旋转雨刮拨杆上的滚轮，调节雨刮刮刷速度。\n2. 当雨量光线传感器检测到降雨强度时，会自动开启/关闭雨刮及调节雨刮刮刷速度。\n3. 可以通过向上或向下旋转滚轮来调整自动雨刷的灵敏度。\n\n注意事项：\n\n1. 如果洗涤液在挡风玻璃上冻结，请勿使用洗涤器。\n2. 在雨刮片处于维修位置或使用自动洗车机清洗车辆前，先停用自动刮刷，以免雨刮意外开启，造成不必要的损坏。\n\n遵循以上步骤和注意事项，即可正确使用自动雨刷。', 'reference': 'page_64', 'question_keywords': '正确 使用 自动 雨刷', 'question_rewriting': '[我应该怎样正确操作自动雨刷?,怎样才是使用自动雨刷的正确方式?]'}
# 46 {'question': '问题：如果自动雨刷灵敏度过高，应该如何调整以减少其对小雨的反应？', 'answer': '根据给定的资料，如果自动雨刷对小雨的反应过于敏感，您可以通过以下方法进行调整：\n\n向下旋转雨刮拨杆上的滚轮，这样可以降低自动雨刷的灵敏度。当灵敏度降低后，雨刷对小雨的反应也会减弱，从而减少在轻微雨水情况下的活动频率。\n\n所以，对于上述四个改写后的问题，调整措施是一样的：通过向下旋转滚轮来降低自动雨刷对小雨的敏感度，使其不那么容易在小雨时启动，从而减少在轻微雨水时的活动频率。', 'reference': 'page_64', 'question_keywords': '自动雨刷 灵敏度 高 调整 小雨 反应', 'question_rewriting': '[1：如何调低自动雨刷对小雨的敏感度?\n2：自动雨刷对小雨反应过于敏感,调整方法有哪些?\n3：我想让自动雨刷不那么容易在小雨时启动,调整措施是怎样的?\n4：如何降低自动雨刷在遇到轻微雨水时的活动频率?]'}
# 47 {'question': '如何正确开启或关闭后雨刮倒车联动功能？', 'answer': '根据给定的资料，正确开启或关闭后雨刮倒车联动功能的方法如下：\n\n在中央显示屏中，点击“-车辆设置-雨刮”，进入雨刮设置界面。在此界面中，您可以找到开启或关闭后雨刮倒车联动功能的选项。点击相应的选项，即可激活或取消后雨刮与倒车时的联动效果。\n\n另外，根据第66页的内容，您还可以直接点击开启/关闭后雨刮倒车联动功能。\n\n为确保正确操作，请遵循以下注意事项：\n1. 在操作前确保车辆处于停车状态。\n2. 仔细阅读屏幕上的提示，按照指示进行操作。\n\n这样，您就可以合适地设置后雨刮与倒车功能的联动开启或关闭。', 'reference': 'page_66', 'question_keywords': '正确 开启 关闭 后雨刮 倒车 联动功能', 'question_rewriting': '[怎样才能准确激活或取消后雨刷与倒车时的联动效果?,如何合适地设置后雨刮与倒车功能的联动开启或关闭?]'}
# 48 {'question': '如何判断后雨刮倒车联动功能是否已经开启？', 'answer': '要判断后雨刮倒车联动功能是否已经开启，可以通过以下步骤：\n\n1. 首先，在车辆中央显示屏中点击“车辆设置”，然后选择“雨刮”。\n\n2. 进入雨刮设置界面后，检查是否存在关于后雨刮倒车联动的选项。\n\n3. 如果有此选项，查看该选项的状态，通常会有“开启”或“关闭”的标识来表明后雨刮倒车联动功能是否激活。\n\n另外，也可以直接通过物理操作来检查后雨刮器在倒车时的自动启动功能是否设置成功：\n\n1. 将车辆挂入倒挡（R）。\n\n2. 观察后挡风玻璃上的雨刮是否自动启动。\n\n3. 如果雨刮在挂入倒挡后自动启动，则说明后雨刮与倒车联动功能已经成功设置并激活。\n\n结合给定的资料，以上步骤可以帮助您确定后雨刮倒车联动功能是否已经开启。', 'reference': 'page_66', 'question_keywords': '判断 后雨刮 倒车 联动功能 是否 开启', 'question_rewriting': '[怎样确定后雨刷与倒车时的联动功能是否激活?,如何检查后雨刮器在倒车时的自动启动功能是否设置成功?]'}
# 49 {'question': '智能远近光控制开启时，哪个指示灯会点亮？', 'answer': '智能远近光控制开启时，智能远近光控制开启指示灯会点亮。', 'reference': 'page_70', 'question_keywords': '智能远近光控制 指示灯 点亮', 'question_rewriting': '[1：当激活智能远近光灯控制功能时,会有哪个信号灯亮起?,2：在使用智能远近光灯控制的情况下,哪个提示灯会显示?,3：智能远近光控制功能一旦启动,应当留意哪个指示灯亮着?]'}
# 50 {'question': '请问智能远近光控制和低速行人提示音功能是否可以同时开启？', 'answer': '根据给定的资料，智能远近光控制和低速行人提示音功能是两个独立的功能。资料中没有明确指出这两个功能不能同时开启。在第154页中提到，低速行人提示音功能在发动机未启用且车速低于一定值时激活，而第85页中提到智能远近光控制系统主要在夜间或光线较暗的情况下自动调节远近光灯。两者的使用条件和场景不同，但在技术层面上，它们可以同时开启。\n\n因此，根据资料，智能远近光控制和低速行人提示音功能是可以同时开启的。', 'reference': 'page_74', 'question_keywords': '智能远近光控制 低速行人提示音 功能 同时开启', 'question_rewriting': '[请问是否能够同时激活智能远近光灯调节和低速行人警示音系统?,智能远近光灯自动切换和低速提醒行人的声音功能能否一起使用?]'}
# 51 {'question': '问题：哪些警告灯是用来指示车辆灯光系统出现故障的？', 'answer': '当车辆照明系统存在问题或灯组可能出了毛病时，以下警告灯或指示灯可能会亮起：\n\n1. 近光灯指示灯或远光灯指示灯：如果这些指示灯在相应灯光打开时未点亮，或者在未打开相应灯光时错误地点亮，可能意味着车辆照明系统存在问题。\n\n2. 转向指示灯：如果转向指示灯闪烁不正常或者在不拨动转向灯开关时点亮，可能是车辆灯组出现故障的标志。\n\n3. 危险警告灯：当打开危险警告灯开关时，如果两侧转向指示灯不闪烁或者闪烁频率异常，可能表明灯光系统存在问题。\n\n4. 充电接口灯光指示：在充电时，如果绿色常亮表示充电完成，但灯色显示异常，比如红色常亮表示充电故障，可能意味着充电照明系统或充电接口部分出现故障。\n\n5. 外部充电连接警告指示灯：如果在外部充电电缆连接成功后该灯没有点亮，可能是充电指示灯系统的故障。\n\n6. 动力电池电量低指示灯：如果该指示灯在不正确的状态下点亮，比如动力电池电量充足时，它错误地点亮，可能表示相关指示灯系统有故障。\n\n结合给定的资料，以上是能够指示车辆灯光系统出现故障的警告灯或指示灯。其他与车辆灯组相关的故障可能不会直接通过警告灯显示，需要通过专业的检查来诊断。', 'reference': 'page_75', 'question_keywords': '警告灯 车辆 灯光系统 故障', 'question_rewriting': '[哪些指示灯亮起时意味着车辆照明系统存在问题?,哪些警示灯的出现意味着车辆灯组可能出了毛病?]'}
# 52 {'question': '问题：智能远近光控制系统故障警告灯点亮后，驾驶员应该如何操作以保证安全行驶？', 'answer': '当智能远近光控制系统故障警告灯点亮后，驾驶员应立即采取以下措施以保证安全行驶：\n\n1. 立即手动切换远近光灯，避免因系统故障导致的照明不足或对前方车辆产生眩目。\n2. 注意行驶环境，如果在大雾、大雨、风雪天气或光线昏暗的街道上行驶，应更加谨慎，并可能需要频繁手动切换灯光。\n3. 将车辆驶向最近的停车点，并尽快联系Lynk&Co领克中心进行检查和维修，避免继续驾驶可能带来的风险。\n4. 在驾驶过程中保持警惕，随时准备应对可能出现的其他系统故障，确保行车安全。\n\n遵循以上步骤，驾驶员可以在智能远近光控制系统故障警告灯亮起时，尽可能地保障安全行车。', 'reference': 'page_76', 'question_keywords': '智能远近光控制系统 故障警告灯 点亮 驾驶员 操作 安全行驶', 'question_rewriting': '[1：在智能远近光灯控制系统的故障警告灯亮起时,驾驶员需要采取哪些措施以确保行驶的安全性?,2：当智能远近光控制功能出现警示灯亮起,驾驶员应执行哪些步骤来维持安全驾驶?,3：面对智能远近光灯控制系统亮起的故障灯,驾驶员该如何应对以确保行车安全?,4：智能远近光系统警示灯亮起时,驾驶员需遵循哪些程序来保障安全行车?]'}
# 53 {'question': '问题：盲点监测系统出现故障时，应该如何在车辆上进行提示？', 'answer': '盲点监测系统出现故障时，车辆会通过点亮仪表盘上的“盲点监测故障警告灯”来提示驾驶者。该警告灯常亮表示盲点监测系统出现故障，如果是因为盲点监测系统标定未完成，则该警告灯会闪烁。此外，根据第74页的资料，如果车速小于10km/h，驾驶者可以按下方向盘右侧的确认按键，以隐藏相关的提醒界面。', 'reference': 'page_74', 'question_keywords': '盲点监测系统 故障 提示 车辆', 'question_rewriting': '[当盲点监控系统发生故障,车辆应如何提示驾驶者?,遇到盲点检测系统出问题的情况下,车辆会以什么方式向司机发出警告?]'}
# 54 {'question': '问题：盲点监测系统出现故障时，盲点监测故障警告灯常亮，那么当盲点监测系统标定未完成时，该警告灯会如何显示？', 'answer': '根据给定的资料，当盲点监测系统标定未完成时，盲点监测故障警告灯会闪烁，而不是常亮。因此，回答改写后的问题：\n\n1. 如果盲点监测系统尚未完成标定，那么故障警告灯会呈现闪烁的状态。\n2. 当盲点监测系统的标定进程尚未结束，那个警告灯不会保持常亮，而是会闪烁。\n3. 在盲点监测系统尚未完成其标定步骤的情况下，警告灯通常会表现为闪烁。\n4. 盲点监测尚未标定完毕时，相应的故障警示灯不会保持常亮，而是会闪烁。', 'reference': 'page_78', 'question_keywords': '盲点监测系统 故障 警告灯 常亮 标定 未完成 显示', 'question_rewriting': '[1：如果盲点监测系统尚未完成标定,那么故障警告灯会呈现什么样的状态?\n2：当盲点监测系统的标定进程尚未结束,那个警告灯是否会保持亮起?\n3：在盲点监测系统尚未完成其标定步骤的情况下,警告灯通常会有怎样的表现?\n4：盲点监测尚未标定完毕时,相应的故障警示灯会保持常亮吗?]'}
# 55 {'question': '问题：当车辆的哪个警告灯常亮时，表明车身稳定控制系统存在故障？', 'answer': '当车辆的车身稳定控制系统存在故障时，特定的警告灯会持续点亮。根据给定的资料，这个警告灯是“车身稳定控制系统状态指示灯”，它会常亮来表示车身稳定控制系统存在故障。因此，回答您的问题：当“车身稳定控制系统状态指示灯”常亮时，表明车身稳定控制系统存在故障。', 'reference': 'page_157', 'question_keywords': '车辆 警告灯 常亮 车身稳定控制系统 故障', 'question_rewriting': '[1：车身稳定控制系统出现问题时,通常会有哪个特定的警告灯持续点亮?\n2：哪个警告灯如果一直亮着,就表示车辆的车身稳定控制系统有故障?\n3：如果车身稳定控制系统有缺陷,会导致哪个警示灯不断发出信号?\n4：能指示车身稳定控制系统故障的警告灯是哪一个,它会如何显示?]'}
# 56 {'question': '问题：如果车辆的变速器故障警告灯点亮，但变速器性能并未降低，那么可能的原因是什么？', 'answer': '根据给定的资料，如果车辆的变速器故障警告灯点亮，但变速器性能并未降低，可能的原因包括：\n\n1. 故障警告灯误报：有时候，由于传感器或其他电子部件的问题，警告灯可能会错误地点亮。\n\n2. 自检过程：资料提到，“车辆启动后，车辆将进行自检，部分警告灯图标将点亮，并在一段时间后熄灭。”如果警告灯在自检后没有熄灭，可能表明自检过程中存在一个问题。\n\n3. 传感器或线路问题：可能是与变速器相关的某个传感器故障或传感器连接线路出现问题，导致警告灯点亮，但实际上变速器工作正常。\n\n4. 软件或电子控制单元问题：车辆的电子控制单元（ECU）负责监控变速器的工作状态。如果ECU软件出现问题或故障，可能导致误报。\n\n5. 其他系统的影响：有时候，其他系统的故障也可能影响到变速器警告灯。例如，如果冷却液温度高或发动机系统存在故障，可能会引起变速器警告灯点亮。\n\n建议在这种情况下，立即将车辆停放在安全地点，并尽快联系Lynk&Co领克中心进行检查，以确保车辆的安全和性能。', 'reference': 'page_76', 'question_keywords': '变速器 故障 警告灯 点亮 性能 并未 降低 可能 原因', 'question_rewriting': '[如果变速器故障指示灯亮起,然而换挡操作并无异常,可能有哪些潜在问题?,当车辆的变速器故障灯亮了,但变速器似乎还在正常工作,可能有哪些原因导致这种情况?]'}
# 57 {'question': '请问哪些情况下会导致安全带未系警示系统警告灯点亮？', 'answer': '在以下情况下，安全带未系警示系统警告灯会点亮：\n\n1. 当驾乘人员未系紧安全带时，车辆启动后，该警告灯会点亮并发出声音提醒。\n2. 车辆在行驶过程中，驾驶员和/或乘员松开已系上的安全带，此时警告灯会点亮并发出声音提醒。\n3. 若系紧安全带后，安全带未系警示系统警告灯持续点亮，则表明安全带系统可能出现了故障。\n\n需要注意的是，此警告灯的设计是为了提醒驾乘人员系好安全带，以保障行车安全。如果警告灯持续点亮或出现异常，建议及时将车辆停在安全地点，并联系专业的维修服务中心进行检查。', 'reference': 'page_78', 'question_keywords': '安全带 未系 警示系统 警告灯 点亮 情况', 'question_rewriting': '[请问在哪些情形下安全带未系提示灯会亮起?,请问哪些情况会触发车辆的安全带未系警告灯?]'}
# 58 {'question': '问题：如何判断安全带系统是否出现故障？', 'answer': '根据给定的资料，判断安全带系统是否出现故障的方法如下：\n\n1. 检查仪表显示屏和中央显示屏是否有安全带相关的警告/指示消息。如果显示屏上出现安全带未系警示系统警告灯点亮的情况，这表明系统检测到驾乘人员的安全带未系紧。\n\n   - 如果系紧安全带后指示灯持续亮，则可能表明安全带系统出现故障。\n\n2. 如果在中央显示屏中点击进入“车辆数据”界面，也可以查看到安全带系统的状态。\n\n   - 如果显示安全带系统有故障提示，请了解这些图标的含义和相应的处理措施。\n\n如果通过以上步骤检查发现安全带系统工作异常，建议采取以下措施：\n\n- 请参见车辆使用手册中关于安全带的章节（页码99），了解如何处理安全带故障。\n- 如果无法解决问题，请联系Lynk&Co领克中心寻求帮助。\n\n综上，通过观察仪表显示屏上的警告灯和中央显示屏的消息提示，可以判断安全带系统是否出现故障。', 'reference': 'page_78', 'question_keywords': '安全带 系统 故障 判断', 'question_rewriting': '[如何识别安全带是否有问题?,怎样检查安全带系统是否工作异常?]'}
# 59 {'question': '如何设置和调整机舱盖/车门/尾门/安全带提醒界面的显示？', 'answer': '根据给定的资料，您可以设置和调整机舱盖/车门/尾门/安全带提醒界面的显示方法如下：\n\n在机舱盖/车门/尾门未关闭或安全带未系时，仪表显示屏将红色高亮显示未关闭机舱盖/车门/尾门或未系安全带座椅的提醒界面。\n\n要隐藏这些提醒界面，当车速小于10km/h时，可以按下方向盘右侧的确认按键。这样，就可以暂时关闭这些提醒界面。\n\n此外，在组合仪表中，还可以进行一些设置项的调整：\n\n1. 通过组合仪表设置菜单可以查看车辆状态、胎压状态、机油状态等信息（行程信息）。\n2. 可以设置导航中的“家”和“公司”两个快捷地址。\n3. 可以通过多媒体功能播放音乐等。\n4. 可以通过电话功能拨打电话。\n\n但是，资料中并未明确说明如何直接修改或配置这些提醒界面的具体设置，如更改提醒界面的显示内容或方式。如果需要进行此类更深入的设置或改动，可能需要按照车辆的用户手册指引，或者联系Lynk&Co领克中心进行咨询。\n\n综上所述，根据资料提供的信息，可以进行基本的显示界面管理和调整，但具体的设置和修改可能需要进一步的操作指引或专业支持。', 'reference': 'page_80', 'question_keywords': '设置 调整 机舱盖 车门 尾门 安全带 提醒界面 显示', 'question_rewriting': '[\n    "我应该如何对发动机盖/车门/后门/安全带提示的屏幕进行设定与修改?",\n    "怎样进行机盖/车门/尾门/安全带提示信息的显示屏设置与改动?",\n    "机舱盖/车门/尾门/安全带提醒的显示屏设置和调节方式是怎样的?",\n    "我想了解如何配置并修改机舱盖/车门/尾门/安全带警告的显示界面。"\n]'}
# 60 {'question': '问题：如果组合仪表显示屏上出现红色高亮提示未关闭机舱盖/车门/尾门或未系安全带，那么如何才能关闭这个提示？', 'answer': '根据给定的资料，如果组合仪表显示屏上出现红色高亮提示未关闭机舱盖/车门/尾门或未系安全带，可以通过以下步骤关闭这个提示：\n\n1. 确保所有机舱盖、车门和尾门都已关闭。\n2. 确保所有驾乘人员都已系好安全带。\n3. 当车速小于10km/h时，按下方向盘右侧的确认按键。\n\n按照上述步骤操作后，组合仪表上的红色高亮提示应该会消失。如果提示仍然存在，可能需要检查相关系统是否存在故障，并联系Lynk&Co领克中心进行检查。', 'reference': 'page_80', 'question_keywords': '组合仪表 显示屏 红色高亮 提示 未关闭 机舱盖 车门 尾门 未系 安全带 关闭 提示', 'question_rewriting': '[\n    1: 当组合仪表上的显示屏出现红色高亮提醒显示机舱盖、车门或尾门未关闭以及安全带未系时,该如何消除这一提示?\n    2: 遇到仪表盘显示屏以红色高亮提示机舱盖、车门、尾门未关闭或未系安全带的情况,该如何让这个提示消失?\n]'}
# 61 {'question': '如何通过组合仪表设置项调整远近光灯？', 'answer': '您可以通过以下步骤通过组合仪表设置项来调整远近光灯：\n\n1. 首先，确保车辆启动且挡位不在P挡。\n2. 在组合仪表上，滚轮旋转到近光灯启用的位置。这样，近光灯、前后位置灯和后牌照灯会被启用。\n3. 若要切换到远光灯，继续将滚轮旋转到远光灯启用的位置。\n4. 然后，向前推动拨杆，以启用远光灯。\n\n注意：当组合仪表显示车门/安全带提醒界面时，需要先按下方向盘右侧的确认按键，才能进入设置菜单进行灯光调整。\n\n这些步骤将帮助您通过组合仪表的设置项来调整远近光灯的模式。', 'reference': 'page_82', 'question_keywords': '组合仪表 设置项 调整 远近光灯', 'question_rewriting': '[\n    "我应该如何操作组合仪表来调节远光灯和近光灯?",\n    "在进行远近光灯调整时,我应该怎样通过仪表盘的设置来进行?",\n    "调整远近光灯的过程中,组合仪表有哪些设置步骤?",\n    "我可以通过哪些组合仪表的设置来改变远光灯和近光灯的模式?"\n]'}
# 62 {'question': '如何在行驶过程中快速切换远近光灯？', 'answer': '在行驶过程中，要快速切换远近光灯，可以通过以下步骤进行：\n\n1. 驾驶员应该首先确保自己的车辆配备了智能远近光控制系统。如果配备了此系统，在满足以下条件的情况下，系统会自动切换远近光灯：\n   - 车速超过40km/h。\n   - 环境光线较暗。\n\n2. 如果需要手动快速切换远近光灯，可以通过以下操作进行：\n   - 根据第82页的资料，可以通过滚轮旋转到相应的位置来启用近光灯或远光灯。当需要远光灯时，向前推动拨杆启用远光灯。\n\n3. 如果没有智能远近光控制系统，需要手动切换时，可以通过以下方式：\n   - 根据第83页的资料，在需要远光灯的情况下，将滚轮旋转到远光灯启用的位置，并向前推动拨杆。\n\n需要注意的是：\n- 在遇到大雾、大雨、风雪天气、明亮的月光下、冻雨天气、灯光昏暗的街道、迎面车辆前雾灯亮起、道路上有行人、存在反光物、迎面车辆灯光被遮挡等情况下，可能需要手动切换远近光灯。\n- 在使用非原装挡风玻璃时，智能远近光控制系统可能无法正常工作。\n\n总之，在行驶过程中快速切换远近光灯，可以通过智能系统自动切换或手动操作拨杆和滚轮来实现。在操作时，需遵守交通规则和确保安全。', 'reference': 'page_85', 'question_keywords': '行驶 切换 远近光灯', 'question_rewriting': '[如何在驾驶时迅速变换远近光?, 行驶中怎样快速切换远近照明?]'}
# 63 {'question': '如何确保前大灯自动开启/关闭功能及自动雨刮功能正常使用？', 'answer': '为确保前大灯自动开启/关闭功能及自动雨刮功能正常使用，需要注意以下几点：\n\n1. 确保雨量光线传感器未被遮挡，它位于前挡风玻璃上部内后视镜三角区域。若被遮挡，前大灯的自动开启/关闭功能和自动雨刮功能可能无法正常工作。\n\n2. 定期清洁挡风玻璃，特别是雨量光线传感器所在区域，以保证传感器可以准确检测外界环境光照强度。\n\n3. 使用合格且适合当地气候条件的洗涤液，避免在低温天气中使用未添加防冻剂的洗涤液，以防洗涤液结冰影响雨刮和洗涤器正常工作。\n\n4. 避免在挡风玻璃干燥或存在尘土、冰雪等异物的情况下使用雨刮，以防损伤雨刮片和挡风玻璃。\n\n5. 定期检查雨刮片，若有橡胶硬化、裂纹或不能刮洗某个区域的情况，应及时更换。\n\n6. 若使用自动洗车机清洗车辆或雨刮片处于维修位置，应先停用自动刮刷功能，以防雨刮意外开启造成损坏。\n\n7. 在驾驶前准备阶段，通过旋转雨刮拨杆上的滚轮，调节自动雨刷的灵敏度，以适应不同的降雨强度。\n\n通过以上措施，可以保证前大灯自动开启/关闭功能及自动雨刮功能的正常使用。', 'reference': 'page_84', 'question_keywords': '确保 前大灯 自动 开启/关闭 功能 自动雨刮 功能 正常 使用', 'question_rewriting': '[如何保证前大灯能够正确地自动启闭以及自动雨刷功能正常运作?,怎样确保车辆的前大灯自动开关和自动雨刷系统正常工作?]'}
# 64 {'question': '问题：如果雨量光线传感器被遮挡，如何确保前大灯自动开启/关闭功能和自动雨刮功能的正常使用？', 'answer': '结合给定的资料，无法回答问题。资料中明确提到，如果雨量光线传感器被遮挡，可能会导致前大灯自动开启/关闭功能及自动雨刮功能无法正常使用，但并未提供在遮挡情况下保证这些功能正常使用的具体方法。', 'reference': 'page_84', 'question_keywords': '雨量 光线传感器 遮挡 前大灯 自动开启/关闭 自动雨刮 功能 正常使用', 'question_rewriting': '[如何遮挡雨量光线传感器时,保证前大灯自动启闭和自动雨刷功能不受影响?, 当雨量传感器被挡住,怎样才能让车辆的自动大灯和自动雨刷继续正常工作?]'}
# 65 {'question': '如何确保大灯随动转向功能在适当的时候工作？', 'answer': '为确保大灯随动转向功能在适当的时候工作，首先需要确保以下条件得到满足：\n\n1. 根据第70页的内容，必须开启智能远近光控制，这样大灯随动转向功能才能激活。\n\n2. 根据第86页的描述，大灯随动转向功能主要在以下情况下启用：\n   - 在黄昏或夜间驾驶。\n   - 车速高于10km/h。\n   - 开启了近光灯或远光灯。\n\n3. 确保车辆设置正确，可以在中央显示屏的“车辆设置”中选择“外部照明”，进入设置界面检查并确认大灯随动转向功能被激活。\n\n4. 需要检查第72页中提到的大灯相关警告灯，例如“大灯高度自动调节功能故障警告灯”和“大灯随动转向功能失效警告灯”，如果这些警告灯点亮，说明大灯随动转向功能可能无法正常工作，需要及时进行维修或检查。\n\n满足这些条件后，大灯随动转向功能就会在正确的时间（例如在转弯过程中）自动调节近光灯的照射角度，提供更好的弯道视野，确保驾驶安全。', 'reference': 'page_86', 'question_keywords': '大灯 随动转向 功能 适当时候 工作', 'question_rewriting': '[如何保证大灯随转功能能在需要时正常运作?, 大灯随动转向功能怎样在正确的时间发挥效用?]'}
# 66 {'question': '问题：大灯随动转向功能在哪些情况下会自动关闭？', 'answer': '根据给定的资料，大灯随动转向功能会在以下特定情境下自动停止工作或失效：\n\n1. 当车辆停止，且挡位处于P挡时，根据第83页内容，车灯会熄灭，这意味着大灯随动转向功能也会停止工作。\n2. 如果关闭了智能远近光控制，根据第70页内容，随动转向功能依赖于智能远近光控制系统的开启状态，关闭该控制可能会影响随动转向功能的正常工作。\n3. 在车速低于10km/h时，根据第86页内容，大灯随动转向功能不会启用，因此在这种情况下也可以看作是自动失效。\n4. 如果没有开启近光灯或远光灯，同样根据第86页内容，随动转向功能不会启用。\n\n此外，如果遇到系统故障，如第72页所述，大灯随动转向功能失效警告灯点亮，表明该功能可能会自动失效。\n\n综上所述，大灯随动转向功能会在车辆停止、P挡位、智能远近光控制系统关闭、车速低于10km/h、未开启近光灯或远光灯，以及系统故障的情况下自动关闭或失效。', 'reference': 'page_86', 'question_keywords': '大灯随动转向 功能 自动关闭 情况下', 'question_rewriting': '[大灯随动转向系统在哪些特定情境下会自动停止工作?, 在哪些情况下随动转向大灯会自动失效?]'}
# 67 {'question': '如何打开和关闭左前阅读灯？', 'answer': '根据给定的资料，要打开和关闭左前阅读灯，您需要触摸位于车顶控制台上的左前阅读灯开关区域。简单触摸该区域可以打开或关闭左前阅读灯。如果需要调节亮度，可以长按该开关区域进行调节。', 'reference': 'page_88', 'question_keywords': '打开 关闭 左前 阅读灯', 'question_rewriting': '[怎样操作左前阅读灯的开关?, 如何进行左前照明灯的开启与关闭?]'}
# 68 {'question': '请问如何设置门控灯的功能？', 'answer': '根据给定的资料，要设置门控灯的功能，您需要在车顶控制台找到相关的照明开关。具体操作步骤如下：\n\n1. 触摸左前阅读灯开关区域，可以打开/关闭左前阅读灯。\n2. 开启门控灯功能后，当您打开车门时，阅读灯会点亮。\n3. 所有车门关闭一段时间后，阅读灯会自动熄灭。\n\n资料中没有提供具体的设置步骤来激活门控灯，但通常这种功能是预设的，不需要复杂的设置过程。如果需要进一步调整或确认门控灯的功能，您可以查看车辆的用户手册或联系Lynk&Co领克中心进行咨询。\n\n所以，结合给定的资料，操作门控灯生效的方法主要是通过触摸车顶控制台的相关开关区域。如果需要详细设置，可能需要参考车辆的用户手册或专业指导。', 'reference': 'page_88', 'question_keywords': '设置 门控灯 功能', 'question_rewriting': '[如何操作才能让门控灯生效?, 我想知道如何激活门控灯的功能?]'}
# 69 {'question': '如何调整车辆的背光亮度？', 'answer': '根据给定的资料，调整车辆背光亮度的步骤如下：\n\n1. 对于仪表盘背光亮度的调整：\n   - 在中央显示屏中点击“设置”。\n   - 选择“显示”，进入显示设置界面。\n   - 使用调光旋钮来调节亮度。\n   - 如果您希望仪表盘和中央显示屏的背光亮度联动，开启“整车背光联动”选项。\n     - 在白天，如果未开启整车背光联动，调光旋钮仅调节仪表盘背光。\n     - 在夜晚，如果未开启整车背光联动，调光旋钮可同时调节仪表显示屏和开关背光亮度。\n     - 如果开启整车背光联动，调光旋钮可同时调节仪表显示屏、中央显示屏和开关背光亮度。\n\n2. 对于中央显示屏亮度的调整：\n   - 也可以通过车辆功能界面或仪表板上的调光器来调整。\n   - 如果选择自动模式，中央显示屏会根据时间自动切换日间或夜间模式。\n   - 如果需要手动调节，可以在显示设置界面中滑动滑条来调整中央显示屏亮度。\n\n关于车辆内部照明亮度的设置，资料中并没有明确说明如何调整，因此针对“我该如何设置车辆内部照明的亮度?”这个问题，结合给定的资料，无法给出具体答案。可能需要查阅其他相关资料或咨询车辆制造商以获取更多信息。', 'reference': 'page_91', 'question_keywords': '调整 车辆 背光 亮度', 'question_rewriting': '[怎样修改汽车仪表盘的背光强度?, 我该如何设置车辆内部照明的亮度?]'}
# 70 {'question': '问题：如何调整车辆的仪表盘亮度？', 'answer': '根据给定的资料，调整车辆的仪表盘亮度可以通过以下方式：\n\n1. 在中央显示屏中，进入“设置”-“显示”菜单，在这里可以设置仪表盘的日间模式、夜间模式或自动模式。\n   \n2. 使用仪表板上的调光器进行背光亮度的调节，具体步骤请参见资料中提到的“调节背光亮度”（页码90或91）部分。\n\n3. 如果选择了自动模式，仪表盘会根据时间自动切换日间模式和夜间模式，白天显示日间模式，晚上显示夜间模式。\n\n4. 如果需要手动调节亮度，可以在中央显示屏的显示设置界面滑动滑条进行亮度调节。\n\n请根据个人喜好选择合适的方式进行仪表盘亮度的调整。', 'reference': 'page_266', 'question_keywords': '调整 车辆 仪表盘 亮度', 'question_rewriting': '[如何设置汽车仪表板的亮度?, 车辆仪表盘的亮度应该如何修改?]'}
# 71 {'question': '如何调整车内氛围灯的亮度和模式？', 'answer': '要调整车内氛围灯的亮度和模式，您需要进行以下操作：\n\n1. 亮度和颜色调整：\n   - 在中央显示屏中点击“座舱体验”选项。\n   - 然后进入“氛围灯”设置界面。\n   - 在此界面中，您可以调节选中区域的氛围灯颜色和亮度。\n\n2. 模式设置：\n   - 同样在“氛围灯”设置界面中，您可以设置氛围灯的不同效果模式，如单色、渐变或呼吸效果。\n   - 您还可以点击开启或关闭特定的氛围灯模式，如离车欢送、来电提醒、低燃油提醒、倒车雷达功能以及上车欢迎功能，这些模式都有各自独特的光效。\n\n此外，关于自动模式的设置：\n   - 如果您希望氛围灯能够根据时间自动切换日间或夜间模式，可以在中央显示屏的车辆功能界面选择自动模式。\n   - 或者您可以通过仪表板上的调光器设置背光亮度，并选择日出到日落的自动切换模式或自定义时段切换模式。\n\n通过以上步骤，您可以根据个人喜好调整车内氛围灯的亮度和模式，从而营造出不同的驾驶氛围。', 'reference': 'page_92', 'question_keywords': '调整 车内 氛围灯 亮度 模式', 'question_rewriting': '[如何设置车内氛围灯的明暗和风格?, 如何改变车内氛围灯的光强与显示效果?]'}
# 72 {'question': '如何调整车内氛围灯的颜色和亮度？', 'answer': '根据给定的资料，您可以通过以下步骤调整车内氛围灯的颜色和亮度：\n\n1. **进入氛围灯设置界面**：\n   - 在中央显示屏中点击“座舱体验”。\n   - 选择“氛围灯”进入氛围灯设置界面。\n\n2. **调节颜色和亮度**：\n   - 在氛围灯设置界面中，可以调节选中区域的氛围灯颜色和亮度。\n   - 根据您的需求，选择合适的颜色和亮度。\n\n3. **场景联动设置**：\n   - 如果需要设置特定场景的氛围灯效果，可以在氛围灯设置界面中启用或关闭相应的功能，例如离车欢送、来电提醒、低燃油提醒、倒车雷达、上车欢迎等。\n\n4. **保存设置**：\n   - 调整完成后，确保保存设置。\n\n请注意，具体的操作步骤可能会根据车型的不同而有所差异，但上述步骤提供了一个通用的指南。如果您需要更详细的操作方法，建议参考车辆的用户手册或联系车辆制造商的客服获取更具体的信息。', 'reference': 'page_92', 'question_keywords': '调整 车内 氛围灯 颜色 亮度', 'question_rewriting': '[如何改变汽车内部氛围灯的色彩及其明亮度?, 我要怎样设置车内氛围灯的色彩与亮度?]'}
# 73 {'question': '如何设置氛围灯的颜色效果？', 'answer': '您可以通过以下步骤来设置氛围灯的颜色效果：\n\n1. 在中央显示屏中点击“座舱体验”选项。\n2. 选择“氛围灯”进入氛围灯设置界面。\n3. 在氛围灯设置界面中，您可以调节选中区域的氛围灯颜色和亮度。\n4. 如果您想要更多的颜色效果，比如单色、渐变或呼吸效果，可以在自定义模式中选择所需的效果。\n\n此外，根据您的车辆设置，还可能支持以下功能：\n- 开启或关闭离车欢送功能，车辆熄火时氛围灯会有呼吸渐变熄灭效果。\n- 开启或关闭来电提醒功能，当有来电时，前排氛围灯会变为蓝色闪烁效果。\n- 开启或关闭低燃油提醒功能，当车辆可续航里程低于一定程度时，氛围灯会变成橘色呼吸效果。\n\n通过这些设置，您可以轻松改变车内氛围灯的颜色效果，以符合个人喜好或特定场景的需求。', 'reference': 'page_94', 'question_keywords': '设置 氛围灯 颜色效果', 'question_rewriting': '[怎样调整氛围灯的色彩效果?, 我要如何改变车内氛围灯的颜色设置?]'}
# 74 {'question': '问题：车辆的不同氛围灯效果能否通过远程控制实现？', 'answer': '根据给定的资料，车辆的不同氛围灯效果可以通过Lynk&CoApp进行远程控制实现。在第92页和第93页的内容中，提到了可以通过中央显示屏设置氛围灯的效果、颜色和亮度，以及开启/关闭各种氛围灯模式，如离车欢送、来电提醒、低燃油提醒等功能。在第281页的内容中，说明了Lynk&CoApp具有远程控制功能，可以控制车窗、天窗、空调等，虽然没有直接提到氛围灯，但由于Lynk&CoApp可以控制车辆的部分功能，并且氛围灯的控制已经在车辆设置中提及，因此可以推断出氛围灯效果也可以通过Lynk&CoApp远程控制实现。', 'reference': 'page_94', 'question_keywords': '车辆 氛围灯效果 远程控制 实现', 'question_rewriting': '[\n    "车辆的多彩氛围灯能否通过远程操作进行切换?",\n    "不同的车内氛围灯效果是否可以通过远程方式来调节?"\n]'}
# 75 {'question': '汽车仪表和灯光系统分别由哪些部分组成？', 'answer': '汽车仪表系统通常由多个部分组成，主要包括但不限于以下组件：\n\n1. 速度表：显示车辆当前的速度。\n2. 发动机转速表：显示发动机的转速。\n3. 燃油表：显示剩余燃油量。\n4. 冷却液温度表：显示发动机冷却液的温度。\n5. 多功能显示屏：可以显示行车电脑信息、导航、娱乐系统等。\n6. 警告灯和指示灯：包括但不限于安全带提醒、发动机故障、油压警告等。\n7. 指针和仪表盘：物理指针和仪表盘用来指示各种信息。\n\n而灯光系统则可能包含以下部分：\n\n1. 前大灯：包括近光灯和远光灯。\n2. 转向灯：指示车辆转向意图。\n3. 尾灯：包括制动灯、后转向灯和倒车灯。\n4. 阅读灯和车内照明：为车内提供照明。\n5. 欢迎灯（迎宾灯）：车辆解锁或锁车时，部分车外灯光会点亮。\n6. 伴我回家功能：设置后，车辆锁车后照明会延迟熄灭。\n7. 警示灯和信号灯：例如，高位刹车灯和侧标志灯。\n\n根据给定资料，还提到了全景天窗的控制按钮、空调出风口的控制板以及驾驶辅助系统的设置界面，这些都是现代汽车中可能包含的额外组件，但它们不是仪表盘和灯光系统的核心部分。\n\n综上所述，汽车仪表和灯光系统的具体组成部件可以根据不同的车型和配置而有所不同，但上述列出的是常见的组成部分。', 'reference': 'page_95', 'question_keywords': '汽车仪表 灯光系统 部分 组成', 'question_rewriting': '[\n    "请问汽车的仪表盘和照明系统都包含哪些组件?",\n    "能否列出构成汽车仪表板和灯光装置的各个部分?"\n]'}
# 76 {'question': '请问如何调整汽车仪表盘上的亮度？', 'answer': '根据给定的资料，您可以通过以下方式调整汽车仪表盘的亮度：\n\n1. 使用中央显示屏车辆功能界面：在中央显示屏中选择“设置-显示”，然后进入显示设置界面，在这里可以使用滑条调节中央显示屏亮度。\n\n2. 利用仪表板上的调光器：在仪表板上找到调光旋钮，通过转动旋钮来调节背光亮度。在白天情况下，如果未开启整车背光联动，转动调光旋钮只会调节仪表显示屏的背光亮度；如果开启了整车背光联动，则可以同时调节中央显示屏和开关背光的亮度。\n\n3. 设置自动模式：在中央显示屏的车辆功能界面中，可以选择自动模式，根据时间段或外界环境光照自动切换日间模式和夜间模式。\n\n此外，如果您的车辆配备有抬头显示（HUD），您也可以通过方向盘或中央显示屏调节HUD的亮度和高度。\n\n请注意，在调节亮度时，确保您的车辆处于停止状态，并且在安全的位置进行操作。', 'reference': 'page_91', 'question_keywords': '汽车仪表盘 亮度 调整', 'question_rewriting': '[如何设置汽车仪表板的亮度?, 我应该怎样调节车辆仪表盘的明亮度?]'}
# 77 {'question': '如何正确清洁和维护汽车安全带以保持其最佳性能？', 'answer': '根据给定的资料，正确清洁和维护汽车安全带以保持其最佳性能的方法如下：\n\n1. 清洁：\n   - 使用安全带专用清洁剂和海绵来清洁安全带。\n   - 清洁后，将安全带置于阴凉处彻底干燥后再使用。\n   - 切勿使用漂白剂、染料或化学溶剂清洁安全带，这些材料可能会严重削弱安全带的织物性能。\n\n2. 维护：\n   - 每次行车前按照以下步骤对安全带进行检查：\n     - 检查安全带是否存在扭曲、脏污、严重磨损、割伤或烧伤的情况。\n     - 将安全带锁舌插入锁扣，直到听到“咔哒”声，反方向拉锁舌，检查安全带锁扣固定情况。\n     - 快速拉动安全带，检查安全带自动缩回/拉紧情况。\n   - 如果存在任何异常情况，请立即联系Lynk&Co领克中心。\n\n遵循这些步骤将有助于确保汽车安全带保持最佳性能，为驾乘人员提供最大程度的保护。', 'reference': 'page_319', 'question_keywords': '清洁 维护 汽车安全带 最佳性能', 'question_rewriting': '[怎样恰当地清洗和保养汽车安全带,以确保其性能处于最佳状态?, 如何对汽车安全带进行适当的清洁与维护,以维持其最优的工作性能?]'}
# 78 {'question': '问题：如何判断安全带的锁舌是否已经正确地插入锁扣？', 'answer': '根据给定的资料，要判断安全带的锁舌是否已经正确地插入锁扣，可以按照以下步骤进行检查：\n\n1. 调节座椅到合适的位置。\n2. 缓慢拉出安全带，将锁舌插入锁扣中。\n3. 听见“咔哒”声，这表明锁舌已经正确地插入锁扣中。\n4. 为了进一步确认，可以反向拉锁舌，检查安全带锁扣固定情况。\n\n以上步骤来源于第101页内容中关于正确使用安全带的说明，以及第100页内容中关于安全带检查的说明。\n\n所以，当你听到“咔哒”声，并且通过反向拉锁舌确认锁扣固定良好时，可以判断安全带的锁舌已经正确地插入锁扣中。', 'reference': 'page_100', 'question_keywords': '安全带 锁舌 插入 锁扣 判断 正确', 'question_rewriting': '[如何确定安全带锁舌是否正确到位?, 如何检查安全带是否已经准确插入锁扣中?]'}
# 79 {'question': '孕妇在驾驶车辆时，为了降低受伤风险，应该采取哪些措施？', 'answer': '孕妇在驾驶车辆时，为了降低受伤风险，应该采取以下措施：\n\n1. **咨询医生**：在驾驶车辆前，应先咨询医生是否能够安全驾驶。\n\n2. **调整座椅位置**：保证可以正常操控车辆的前提下，调节座椅位置，使腹部远离方向盘。\n\n3. **正确使用安全带**：\n   - 肩部安全带应从肩部上面绕过，然后绕过胸部中间，至腹部的侧面。\n   - 腰部安全带应平贴在大腿处，置于腹部下方尽可能靠下的位置。\n   - 松开安全带时，应在按下解锁按钮之前握住安全带，以防止安全带缩回速度过快。\n\n4. **安全气囊注意事项**：正确系紧安全带，因为安全气囊与安全带配合使用，可以为乘员头部和胸部提供附加保护。\n\n5. **避免驾驶时潜在风险**：考虑到驾驶辅助系统（如CMSF）的局限性，孕妇应额外注意驾驶环境，避免在恶劣天气或能见度低的情况下驾驶，并始终保持安全的距离和速度。\n\n采取这些措施可以帮助孕妇在驾驶过程中减少受伤的风险，保障自身和胎儿的安全。', 'reference': 'page_102', 'question_keywords': '孕妇 驾驶车辆 降低 受伤风险 措施', 'question_rewriting': '[孕妇在开车时应该如何做才能减少受伤的可能性?, 孕妇为了安全驾驶,需要采取哪些防范措施?]'}
# 80 {'question': '在孕期驾驶或乘坐车辆时，如果安全气囊未能正确部署，对孕妇和胎儿会有什么潜在的风险？', 'answer': '在孕期驾驶或乘坐车辆时，如果安全气囊未能正确部署，对孕妇和胎儿可能会带来以下潜在风险：\n\n1. 增加受伤风险：安全气囊的主要作用是在碰撞时减少乘员头部和胸部的伤害。如果安全气囊未能展开，孕妇在碰撞时可能会遭受更大的冲击力，导致严重受伤。\n\n2. 影响胎儿安全：未展开的安全气囊无法为孕妇腹部提供额外的保护，这可能导致胎儿受到间接伤害或影响。\n\n3. 安全带未能充分发挥作用：安全气囊与安全带协同工作，提供更全面的保护。如果安全气囊未能启动，仅依靠安全带可能无法充分减少碰撞对孕妇腹部的冲击。\n\n4. 事故后果加重：在发生碰撞时，未展开的安全气囊可能导致事故后果更加严重，对孕妇和胎儿的生命安全构成更大威胁。\n\n总之，孕期中若车辆的安全气囊在碰撞时未能恰当启动，可能会增加孕妇和胎儿的受伤风险，甚至对生命安全造成严重威胁。因此，孕妇在驾驶或乘坐车辆时应确保安全气囊系统正常工作，并始终正确使用安全带。', 'reference': 'page_102', 'question_keywords': '孕期 驾驶 乘坐车辆 安全气囊 部署 孕妇 胎儿 潜在风险', 'question_rewriting': '[\n    1：孕期中,若车辆的安全气囊在碰撞时未能恰当启动,可能给孕妇和婴儿带来哪些危险?\n    2：在怀孕期间,如果遇到事故时车辆的安全气囊没有正常工作,对母亲和胎儿可能产生哪些安全隐患?\n]'}
# 81 {'question': '在什么情况下，安全气囊可能不会展开？', 'answer': '在以下特定情境中，安全气囊可能不会展开：\n\n1. 碰撞点集中在一个位置（如树木或防护杆）上，且碰撞力不够大。\n2. 车身结构受损程度并不是决定安全气囊是否展开的唯一因素。\n3. 被后方车辆追尾时。\n4. 车辆发生侧面碰撞时。\n5. 车辆低速与固定物（如前方车辆或墙面）或柔性物体（如雪堆或灌木丛）发生碰撞时。\n6. 车辆与集装箱货车碰撞或钻入大车下部时。\n7. 车辆撞到容易变形的物体，如树木等。\n8. 车辆与台阶等低矮物体发生碰撞时。\n9. 车辆突然落入深坑或深沟时。\n10. 车辆发生侧翻时。\n\n此外，以下因素可能导致安全气囊未能弹出：\n\n1. 如果车辆未启动，安全气囊系统不会运行。\n2. 如果驾乘人员未使用或未正确使用安全带，安全气囊在碰撞事故中提供的保护作用会减小或失效。\n3. 碰撞和冲击的具体情况，包括撞击的程度、角度、速度和受撞击物体，这些都是决定安全气囊是否展开的重要因素。\n4. 安全气囊控制模块监控各个装置的运行状况，如果未检测到满足触发条件的碰撞事件，安全气囊不会展开。\n5. 安全气囊装置只能提供一次性的事故防护功能。如果安全气囊在之前的事故中已经触发，但没有更换，则可能不会在后续的碰撞中展开。', 'reference': 'page_104', 'question_keywords': '安全气囊 展开情况\n', 'question_rewriting': '[\n    在哪些特定情境中,安全气囊可能未能启动?\n    哪些因素可能导致安全气囊未能弹出?\n]'}
# 82 {'question': '在上述情况下，安全气囊未能展开的车辆乘员可能遭受何种程度的伤害？', 'answer': '在上述情况下，安全气囊未能展开的车辆乘员可能会遭受较为严重的伤害。因为安全气囊的设计是为了在发生特定碰撞时减少乘员头部和胸部的伤害，如果安全气囊未能按预期工作，那么在碰撞事故中，乘员将失去这一重要的保护措施，从而可能导致头部、胸部、腹部等部位受到直接冲击，伤害的严重程度会根据碰撞的强度、速度、角度以及乘员是否正确佩戴安全带等因素而有很大差异。总的来说，安全气囊未能展开时，乘员受到的伤害程度可能会更高，剩余的防护措施只能依赖安全带和其他车辆安全系统，因此风险较大。', 'reference': 'page_104', 'question_keywords': '安全气囊 未能展开 车辆乘员 剩余程度 剩害\n \n\n（注：关键词提取可能因语境和需求不同而有所差异，这里提取的是与安全气囊未展开相关的主要元素。）', 'question_rewriting': '[在这种情形中,未能弹出安全气囊的车辆内人员可能会受到怎样级别的伤害?, 当车辆的安全气囊在上述情况中没有启动时,乘客可能会受到多严重的伤害?]'}
# 83 {'question': '远端安全侧气囊主要在什么情况下展开？', 'answer': '远端安全侧气囊主要在车辆发生侧面碰撞的情况下展开，以保护乘员头部、胸部、腹部、肩部、髋部，尽可能减少伤害。这是针对装有远端安全侧气囊的车型而言的。（资料来源于第106页内容）', 'reference': 'page_106', 'question_keywords': '远端 安全 侧气囊 展开情况', 'question_rewriting': '[\n    1：在哪些特定情境下远端安全侧气囊会被触发展开?\n    2：远端安全侧气囊通常在什么样的紧急情况下发挥作用展开?\n]'}
# 84 {'question': '远端安全侧气囊在受到侧面碰撞时能展开多长时间？', 'answer': '结合给定的资料，无法回答问题。资料中并未提供关于远端安全侧气囊在受到侧面碰撞时能展开的具体时间信息。', 'reference': 'page_103', 'question_keywords': '远端 安全 侧气囊 受到 侧面碰撞 展开时间', 'question_rewriting': '[1: 远端侧面安全气囊在侧面撞击情况下保持开启状态多久?\n2: 当车辆遭受侧面冲击时,侧边的远端安全气囊能够持续打开多长时间?\n3: 遭受侧面碰撞时,远端侧气囊能够维持多久的展开状态?]'}
# 85 {'question': '如何通过中央显示屏设置车窗和遮阳帘的功能？', 'answer': '通过中央显示屏设置车窗和遮阳帘的功能，您可以按照以下步骤操作：\n\n1. 点击中央显示屏上的“车辆设置”选项。\n2. 在设置菜单中选择“车窗和遮阳帘”。\n3. 在此界面下，您可以进行以下个性化配置：\n   - 打开或关闭锁车自动关窗功能：设置在锁车时是否自动关闭所有车窗和全景天窗。\n   - 控制车窗锁止功能：对于后门车窗，可以开启或停用锁止功能，以防止儿童等乘员误操作。\n   - 操作遮阳帘：打开或关闭遮阳帘，根据需要调整车内光线和隐私。\n   - 控制全景天窗：可以设置全景天窗的开闭状态，包括起翘和滑动功能。\n\n如果需要使用Lynk&CoApp进行操作，也可以通过以下方式：\n\n1. 打开Lynk&CoApp，登录账户。\n2. 选择相应的图标来打开或关闭车窗和遮阳帘。\n3. 通过滑动滑块来精细控制天窗或遮阳帘的开合程度。\n\n请注意，在进行这些设置之前，确保车辆点火开关处于相应位置，并且按照车辆说明书中的指导进行操作，以确保系统正常工作。如果设置后功能不正常，建议联系Lynk&Co领克中心进行咨询或维修。', 'reference': 'page_111', 'question_keywords': '中央显示屏 设置 车窗 遮阳帘 功能', 'question_rewriting': '[如何在中央显示屏上调整车窗与遮阳帘设置?, 如何在车辆中央屏幕上进行车窗及遮阳帘功能的个性化配置?]'}
# 86 {'question': '问题：如果想要在行驶过程中只关闭驾驶员侧车窗，应该按照怎样的步骤操作？', 'answer': '在行驶过程中，如果您只想关闭驾驶员侧的车窗，可以按照以下步骤操作：\n\n1. 确保车辆正在行驶，并且您的注意力不会因为操作车窗而分散。\n2. 使用驾驶员侧车门上的车窗控制按钮。\n3. 按下或拉起车窗控制按钮，直到驾驶员侧的车窗完全关闭。\n\n需要注意的是，在操作车窗时，要确保不会影响驾驶安全。此外，如果车窗在自动关闭过程中碰到了障碍物，车窗会启用防夹功能，停止关闭并重新打开。\n\n如果在某些情况下车窗的自动升降功能无法正常工作，可能需要进行车窗初始化操作，具体步骤请参考手册中提供的初始化步骤。\n\n请始终遵守交通法规，确保在操作车窗时不会对您或其他道路使用者的安全构成威胁。', 'reference': 'page_109', 'question_keywords': '行驶 过程中 关闭 驾驶员 车窗 步骤 操作', 'question_rewriting': '[如何才能在行驶中单独关闭驾驶座的窗户?, 在行驶时,我该如何操作才能仅关闭司机侧的窗户?]'}
# 87 {'question': '全景天窗在什么情况下会自动滑动打开？', 'answer': '全景天窗会在以下情况下自动滑动打开：\n\n1. 当车辆点火开关转至I或以上挡位时，可以通过车顶控制面板上的控制按钮操作全景天窗和遮阳帘。在这种情况下，如果向上按下控制按钮后边缘，全景天窗将自动滑动打开。\n\n2. 如果全景天窗和遮阳帘处于完全关闭状态，向上按下控制按钮后边缘，全景天窗玻璃的后边缘会打开一定位置，同时遮阳帘也会打开一定位置。\n\n3. 从打开位置调整至起翘位置后，如果再次操作控制按钮，起翘移动会停止，全景天窗将自动滑动打开。\n\n这些是资料中提及的关于全景天窗自动滑动打开的特定情境。', 'reference': 'page_110', 'question_keywords': '全景天窗 自动 滑动 打开 什么情况 下 会 打开', 'question_rewriting': '[什么时候全景天窗会自动展开滑动?, 在哪些特定情境下全景天窗会自动开启?]'}
# 88 {'question': '问题：如果全景天窗和遮阳帘都处于打开状态，想要关闭它们，应该按照什么步骤操作？', 'answer': '如果全景天窗和遮阳帘都处于打开状态，想要关闭它们，可以按照以下步骤操作：\n\n1. 使用车顶控制面板上的控制按钮。\n2. 如果要关闭全景天窗的后半部分（固定部分不活动），可以起翘/滑动前半部分。\n3. 向下/前拨动控制按钮后边缘，使天窗起翘关闭。\n4. 如果要关闭遮阳帘，可以通过按控制按钮使遮阳帘和全景天窗同时关闭。\n   - 如果全景天窗和遮阳帘处于完全关闭状态，短时间内将控制按钮按到底两次，遮阳帘和全景天窗会同时关闭。\n   - 或者，如果全景天窗处于打开状态，向上按下控制按钮后边缘，全景天窗将自动滑动关闭（按到底）。\n5. 如果需要通过Lynk&CoApp关闭天窗和遮阳帘，可以登录Lynk&CoApp，按下相应的图标来关闭天窗或遮阳帘。\n\n请注意，具体的操作步骤可能会根据车辆设置和Lynk&CoApp的更新有所不同，以上步骤是根据给定的资料提供的。如果遇到任何问题或步骤不适用，建议查看Lynk&CoApp的最新说明或联系Lynk&Co领克中心获取帮助。', 'reference': 'page_110', 'question_keywords': '全景天窗 遮阳帘 关闭 步骤 操作', 'question_rewriting': '[\n    "如何进行全景天窗和遮阳帘的关闭操作,当它们都处于开启状态时?",\n    "当全景天窗和遮阳帘展开时,我需要知道关闭它们的正确步骤是什么?"\n]'}
# 89 {'question': '如何确保儿童在车内时的安全？', 'answer': '为确保儿童在车内时的安全，以下是一些重要的措施：\n\n1. 使用合适的儿童安全座椅：确保儿童坐在适合其年龄和体型的儿童安全座椅中。对于较小的儿童，建议使用反向儿童安全座椅，并根据孩子的体型选择合适的座椅。\n\n2. 正确安装儿童安全座椅：请按照座椅制造商的说明书和当地法规，将儿童安全座椅正确安装在车内。对于顶部系带固定装置，确保顶部系带穿过头枕的两根杆体，并正确挂扣。\n\n3. 使用ISOFIX固定装置：如果车辆配备ISOFIX系统，请确保按照说明书将儿童安全座椅安装在ISOFIX固定装置中，并通过拉动和摇晃来检查是否固定到位。\n\n4. 启用儿童锁：在行车前，启用后门的儿童锁，以防止儿童在车内打开车门。\n\n5. 确保儿童不接触危险物品：在无线充电板上不要放置信用卡、硬币、金属钥匙等物品，避免儿童接触这些可能带来危险的物品。\n\n6. 照看儿童：确保行程中始终有成年人照看儿童，防止他们站在或跪坐在座椅上，或待在后备厢区域。\n\n7. 不要单独留儿童在车内：避免让儿童单独留在车内无人照看，也不要让儿童携带车钥匙。\n\n8. 注意智能设备充电安全：不要在驾驶员不在车内时对手机进行无线充电，以防出现安全隐患。\n\n遵循这些措施，可以有效确保儿童在车内的安全。', 'reference': 'page_123', 'question_keywords': '儿童 安全 车内 确保', 'question_rewriting': '[怎样保证孩子在车里的安全呢?, 如何让车内的小孩更安全?]'}
# ...
# 273 {'question': '问题：车辆的漆面保养和维护中，打蜡和抛光分别有什么不同的作用和适用情况？', 'answer': '在车辆的漆面保养和维护中，打蜡和抛光有不同的作用和适用情况。\n\n打蜡主要是为了提供一层保护膜，保护漆面免受外界环境的侵害，如紫外线、酸雨、灰尘等。打蜡的独特效果包括：\n- 形成保护层：打蜡能在汽车漆面上形成一层薄薄的、具有防水和保护作用的蜡膜，有助于防止水和污染物直接侵蚀漆面。\n- 增加光泽：打蜡可以使漆面看起来更有光泽，让车辆外观更加美观。\n- 延缓漆面老化：通过定期打蜡，可以减缓漆面因紫外线照射和氧化导致的老化过程。\n\n打蜡最合适的场合包括：\n- 定期保养：作为车辆日常保养的一部分，定期（如每年至少一次）为车辆打蜡。\n- 汽车新漆后：新喷漆的汽车，在漆面完全硬化后，可以通过打蜡来提供额外的保护。\n- 高污染环境：在多尘、多污染物或极端天气条件下，增加打蜡的频率可以更好地保护漆面。\n\n抛光则是通过去除漆面上的轻微划痕、氧化层和污渍，来恢复漆面的光泽和光滑度。抛光的独特效果包括：\n- 恢复光泽：抛光可以去除漆面上的氧化物和细微划痕，恢复漆面的原始光泽。\n- 减少瑕疵：通过抛光可以减少或消除太阳纹、水渍斑等表面瑕疵。\n- 为打蜡做准备：抛光后的漆面更加光滑，有利于蜡层的附着，提高打蜡效果。\n\n抛光最合适的场合包括：\n- 漆面失去光泽：当车辆的漆面出现氧化、失去光泽时，抛光可以帮助恢复。\n- 有明显的划痕或瑕疵：在漆面上有轻微的划痕或瑕疵，且不影响漆面结构时，可以通过抛光处理。\n- 为特殊活动准备：如果车辆将参加展览、拍卖或重要活动，抛光可以提升车辆的外观，增加吸引力。\n\n需要注意的是，抛光操作相对更为侵入性，可能会逐渐减少漆面的厚度，因此不建议频繁进行抛光处理。同时，在进行打蜡和抛光时，应使用适合自己车型和漆面状况的产品和方法，以免损伤漆面。', 'reference': 'page_318', 'question_keywords': '车辆 漆面保养 维护 打蜡 抛光 作用 适用情况', 'question_rewriting': '[车辆外观护理中,打蜡与抛光各自起到哪些独特效果,它们分别在哪些场合下使用最为合适?]'}
# 274 {'question': '请问Lynk&Co领克车辆的保养周期是如何确定的？', 'answer': 'Lynk&Co领克车辆的保养周期是根据车辆的行驶里程和时间来决定的。Lynk&Co领克的智能驾驶分析系统会结合车辆行驶状况和个体驾驶习惯，给出最合适的保养里程提醒。具体来说，车辆行驶里程或行驶时间达到15,000公里或12个月（以先到者为准）时，仪表显示屏将弹出提示消息，提示车主需要保养车辆。此外，Lynk&Co领克还推荐车主按照智能保养系统提醒的日期到店保养，以保持良好的车辆状况。\n\n制定标准主要依据是车辆的行驶状况和保养需求，旨在确保车辆性能和安全，同时遵循厂家的保养建议。Lynk&Co领克中心还为车主的爱车制订了一整套保养计划，以确保满足所有保养需求，使车主完全满意。技师经过专业培训，精通车辆的保养和维修，推荐使用Lynk&Co领克原厂纯正零件来维修保养车辆，以确保零件的功能和安全性。', 'reference': 'page_320', 'question_keywords': 'Lynk&Co 领克车辆 保养周期 确定', 'question_rewriting': '[1: 领克车辆在进行保养时,其周期是根据什么来决定的?,2: 能否解释一下Lynk&Co领克车辆保养周期的制定标准是什么?]'}
# 275 {'question': '请问Lynk&Co领克智能驾驶分析系统是如何识别和记录驾驶员的驾驶习惯的？', 'answer': 'Lynk&Co领克的智能驾驶分析系统通过收集车辆的行车数据来识别和记录驾驶员的驾驶习惯。具体来说，该系统会结合车辆行驶状况和个体驾驶习惯，给出最合适的保养里程提醒。为了实现这一功能，Lynk&Co领克需要获取车辆的一些行车数据，这些数据反映了驾驶员的驾驶行为和习惯。通过分析这些数据，智能驾驶分析系统能够辨识驾驶员的驾驶习性并进行记录。此外，车辆配备的远程监控系统也会采集并保存车辆各种系统数据，如车速、位置、驱动电机、动力电池和报警信息等，这些数据同样有助于分析驾驶员的驾驶行为。', 'reference': 'page_320', 'question_keywords': 'Lynk&Co 领克 智能驾驶 分析系统 识别 记录 驾驶员 驾驶习惯', 'question_rewriting': '[领克 Lynk&Co的智能驾驶系统是如何对驾驶者的驾驶习性进行辨识和记录的?, 智能驾驶 Lynk&Co领克版是如何监测并记载驾驶者的驾驶行为的?]'}
# 276 {'question': '如何正确地进行汽车保养和维护以延长汽车使用寿命？', 'answer': '为了正确地进行汽车保养和维护以延长汽车使用寿命，可以遵循以下步骤和指导原则：\n\n1. **轮胎保养**：\n   - 定期检查轮胎的气压，确保符合车辆推荐的胎压规格，避免充气不足或充气过量。\n   - 安装新轮胎或维修后，务必检查车轮动平衡，这需要专业技能和专用设备，建议到专业的Lynk&Co领克中心进行。\n   - 避免轮胎接触到润滑脂、润滑油和燃油，防止不必要的损坏。\n   - 定期检查轮胎是否有损坏或异常磨损，及时进行轮胎换位，但请注意轮胎只能前后互换，不能左右互换。\n   - 更换新轮胎后，初期避免高速行驶。\n\n2. **日常驾驶习惯**：\n   - 在新车磨合期间（最初2000km行驶期间），避免高速空转发动机，不要急加速、急刹车，以及避免长时间满载低速或超高速行驶。\n   - 避免以固定车速或发动机转速长时间行驶，选择平坦路面行驶，避免在泥泞或沙土路上行驶。\n\n3. **电气系统维护**：\n   - 定期检查保险丝盒，确保其不受潮、不受污染，避免电路短路或过载。\n   - 更换遥控钥匙电池时，小心操作，避免损坏钥匙或丢失电池。\n\n4. **动力电池和低压蓄电池**：\n   - 电动汽车应避免将车辆停放在温度过高或过低的环境中，不要靠近高温热源。\n   - 动力电池应每月至少充满一次，以保证电池寿命。\n   - 检查低压蓄电池电缆是否正确连接且紧固，避免多次完全放电。\n\n5. **一般注意事项**：\n   - 安装雨刮片等部件时，确保适用于您的车型。\n   - 遵循车辆说明书中的所有指导，如有任何疑问或需要服务，及时联系Lynk&Co领克中心。\n\n通过遵循这些保养和维护的步骤，可以有效提升车辆的使用寿命，确保车辆始终处于良好的技术状态。', 'reference': 'page_304', 'question_keywords': '汽车保养 维护 延长 使用寿命', 'question_rewriting': '[怎样恰当执行汽车的保养和维护工作以使车辆使用周期更长?, 如何实施恰当的汽车维护和保养来提升车辆使用寿命?]'}
# 277 {'question': '汽车发动机内部积碳的主要原因是什么？', 'answer': '汽车发动机内部积碳的主要原因包括但不限于：经常短途行驶、在多尘或多沙地区行驶、频繁制动、在盐碱路上行驶、在山区行驶、经常以低速行驶以及在极冷或极热条件下行驶。随着时间的推移，发动机内会形成油泥和其他沉积物，例如润滑系统和燃油系统喷油器中的油泥、节气门积碳、冷却系统中的水垢等。这些因素都会导致发动机内部积碳的积累。', 'reference': 'page_321', 'question_keywords': '汽车发动机 内部积碳 主要原因', 'question_rewriting': '[哪些因素是导致汽车发动机内部积碳的主要原因?, 汽车发动机内部积碳通常是由什么引起的?]'}
# 278 {'question': '在进行OTA升级时，如果遇到升级失败或更新延迟的提示，应该采取哪些步骤？', 'answer': '在进行OTA升级时，如果遇到升级失败或更新延迟的提示，应按照以下步骤操作：\n\n1. 首先查看车辆是否满足OTA升级条件，如挡位是否位于驻车挡（P）、车辆网络连接是否正常等（参考资料第325页）。\n\n2. 如果不满足升级条件，根据提示信息了解推迟升级的原因，并在满足条件后重新尝试升级（参考资料第325页）。\n\n3. 如果确认车辆满足升级条件但仍然遇到升级失败或延迟，请查看中央显示屏弹出的具体提示信息，并按照提示进行操作（参考资料第326页）。\n\n4. 若倒计时结束时车辆处于未锁止状态，无法进行OTA升级，请重新执行OTA更新流程（参考资料第326页）。\n\n5. 如果以上步骤都无法解决问题，请联系Lynk&Co领克中心寻求帮助（参考资料第326页）。\n\n综上，遇到OTA升级失败或更新延迟时，应先检查车辆状态和升级条件，按照提示信息操作，并在必要时联系专业技术人员协助解决。', 'reference': 'page_326', 'question_keywords': 'OTA升级失败 更新延迟 提示 采取步骤', 'question_rewriting': '[在进行远程在线升级过程中,若出现升级不成功或更新延后的通知,应当遵循哪些解决步骤?, 当接收到OTA升级时遇到失败或延迟的提示信息,该如何操作?]'}
# 279 {'question': '在进行OTA升级时，如果车辆突然断电，应该如何处理？', 'answer': '在进行OTA升级时，如果车辆突然断电，根据给定的资料，可以采取以下措施：\n\n1. 首先确认车辆是否满足OTA升级的条件，例如车辆是否处于驻车挡（P），网络连接是否正常。\n\n2. 如果断电是由于车辆自身原因（如电池电量过低），可以尝试按照资料中第329页提到的步骤检查车辆电池电量，并采取相应措施，如给电池充电。\n\n3. 如果车辆在OTA升级过程中意外断电，请检查中央显示屏是否有升级失败或者更新延迟的提示。如果有的话，按照资料中第326页的建议，先查看车辆是否满足OTA升级条件，再重新进行OTA升级操作。\n\n4. 如果上述步骤无法解决问题，或者断电是由于外部因素导致的，建议联系Lynk&Co领克中心寻求帮助。\n\n5. 在等待处理过程中，请确保车辆处于安全位置，避免影响交通。\n\n综上所述，如果OTA升级时遇到车辆意外断电，应首先自行检查可能的故障原因，并根据车辆提示信息采取相应措施。如果问题无法自行解决，应及时联系专业维修服务。', 'reference': 'page_326', 'question_keywords': 'OTA升级 车辆 断电 处理', 'question_rewriting': '[在进行远程在线升级过程中,如果遭遇车辆电力意外中断,应采取哪些措施?, 在执行OTA更新时遇到车辆意外断电,该如何是好?]'}
# 280 {'question': '在紧急情况下，如果车辆出现故障，应该采取哪些步骤来确保安全并寻求帮助？', 'answer': '在紧急情况下，如果车辆出现故障，以下步骤可以帮助您确保安全并寻求帮助：\n\n1. **立即打开危险警示灯**：这可以通过按下车辆内的危险警示灯按钮来完成，以警示其他道路使用者。\n\n2. **安全停车**：尽量将车辆停在最右侧的紧急停车带或者安全的路边，确保车辆远离行驶车道。\n\n3. **穿戴安全背心**：从手套箱内取出安全背心并穿上，以增加在紧急情况下的能见度。\n\n4. **设置三角警示牌**：从后备厢取出三角警示牌，并将其放置在车辆后方足够远的位置，以警示其他司机。\n\n5. **检查车辆状态**：\n   - 查看仪表显示屏和中央显示屏是否有警告/指示消息，了解这些图标的含义和相应的处理措施。\n   - 检查是否有任何系统功能下降或受限，并采取适当措施解决。\n\n6. **使用紧急救援（SOS）功能**：如果车辆具备SOS功能，可以按住SOS呼叫按钮约2秒，手动激活SOS功能，直接与Lynk&Co领克客户联络中心联系。\n\n7. **手动求助**：如果SOS功能不可用，应使用手机拨打当地紧急救援电话。\n\n8. **避免自行修理车辆**：如果车辆故障复杂，不要尝试自行修理，以免造成更大的安全隐患。\n\n9. **等待救援**：在安全的位置等待救援到来，并遵循救援人员的指示。\n\n通过以上步骤，您可以在紧急情况下确保自己的安全，并及时获得帮助。', 'reference': 'page_330', 'question_keywords': '紧急情况 车辆故障 确保 安全 寻求帮助 步骤', 'question_rewriting': '[紧急情况下车辆发生问题,该如何确保安全并求援?\n在遇到车辆紧急故障时,哪些措施能帮助保障安全并且联系救援?]'}
# 281 {'question': '在紧急情况下，如果车辆的故障警告指示灯图标或消息提示无法正常工作，应该如何处理？', 'answer': '在紧急情况下，如果车辆的故障警告指示灯图标或消息提示无法正常工作，首先应保持冷静，并尝试以下步骤进行处理：\n\n1. 立即减速并尽可能安全地将车辆停到路边，避免影响交通。\n\n2. 检查车辆的基本情况，如燃油、冷却液、轮胎气压等，看是否有明显的故障迹象。\n\n3. 尝试重启车辆，查看是否能够恢复正常工作。\n\n4. 如果问题依旧存在，使用车内提供的应急工具和设备，例如补胎套装等，对车辆进行基本的应急处理。\n\n5. 根据车辆用户手册的指导，进行简单的故障诊断。\n\n6. 如果上述步骤无法解决问题，使用紧急救援（SOS）按键。根据第330页内容，按住SOS按键约2秒，手动激活SOS功能，直接向Lynk&Co领克客户联络中心寻求紧急援助。\n\n7. 如果手动SOS呼叫无法得到回应，车辆位置将会被发送到Lynk&Co领克客户联络中心。\n\n8. 如果有条件，联系附近的汽车维修服务或Lynk&Co领克中心进行现场援助。\n\n在处理此类紧急情况时，请注意个人安全始终是首要考虑。不要尝试自行修理车辆，如果不确定故障原因或无法安全地处理故障，请尽量寻求专业帮助。', 'reference': 'page_330', 'question_keywords': '紧急情况 车辆 故障警告 指示灯 图标 消息提示 无法正常工作 处理', 'question_rewriting': '[在紧急状况下,若汽车故障警示灯或信息提示失效,该如何应对?, 面临紧急状况时,如果车辆的警示灯标志及消息通知出现问题,我们应该采取哪些措施?]'}
# 282 {'question': '紧急道路救援服务对于车辆出现什么问题提供免费服务？', 'answer': '紧急道路救援服务对于以下车辆问题提供免费服务：\n\n1. 在4年或100,000公里范围内，提供不限公里数的免费救援服务。\n2. 超过4年或100,000公里范围之后，提供救援里程100公里（领克中心至施救地单程距离）内的免费服务。\n3. 电瓶问题，如影响车辆正常启动时，提供“搭电”服务。\n4. 车钥匙问题，帮助送取备用钥匙（同城），或采取其他妥善解决方法。\n5. 轮胎问题，根据具体情况（如爆胎/扎胎）提供更换备用轮胎服务，但备用轮胎需车主自行准备。\n\n此外，还包括一些可以在现场解决的简单机械故障，Lynk&Co领克中心会派出专业技师提供救援服务。\n\n需要注意的是，免费服务的具体范围可能受限于车辆使用年限、行驶里程等因素，并且某些服务可能需要车主自行准备相关设备（如备用轮胎）。超出免费服务范围的情况，车主可能需要承担相应费用。', 'reference': 'page_332', 'question_keywords': '紧急道路救援服务 车辆问题 免费服务', 'question_rewriting': '[紧急道路救援通常在哪些车辆问题情况下可以免费提供帮助?, 道路救援服务在哪些特定故障时会提供免费的救援?]'}
# 283 {'question': '问题:如果我的车辆在保修期外抛锚，领克救援服务是否会提供免费的拖车服务？', 'answer': '根据给定的资料，特别是第332页的内容，当您的车辆超出保修期（即超过了4年或100,000公里）且无法行驶时，Lynk&Co领克紧急道路救援服务仍然会提供一定的救援支持。具体来说，救援服务包括在救援里程100公里（领克中心至施救地单程距离）内的免费拖车服务。如果超出这个距离，您可能需要支付额外的费用。\n\n因此，回答您的问题：如果您的车辆在保修期外抛锚，Lynk&Co领克救援服务在救援里程100公里内会提供免费的拖车服务，超出这个范围则需自费。', 'reference': 'page_332', 'question_keywords': '车辆 保修期外 抛锚 领克救援服务 免费拖车服务', 'question_rewriting': '[如果我的车在保修期结束后出现故障,领克是否会免费提供拖车救援?, 当我的车辆超出保修期且无法行驶时,能否获得领克救援的免费拖车支持?]'}
# 284 {'question': '在提供的资料中，提到了哪些情况下顾客车辆的驾驶人员被视为处于醉酒状态？', 'answer': '在提供的资料中，提到以下情况下顾客车辆的驾驶人员被视为处于醉酒状态：\n\n- 当顾客车辆的驾驶人员的血液中的酒精含量超过交通法、机动车行驶法、道路安全法或者《中华人民共和国道路交通安全法》、《中华人民共和国道路交通安全法实施条例》的相关规定时，则视为醉酒。', 'reference': 'page_334', 'question_keywords': '资料 醉酒状态 顾客车辆 驾驶人员', 'question_rewriting': '[1: 在给出的资料里,哪些状况会使得驾驶顾客车辆的驾驶员被认为喝醉了?,2: 根据提供的资料,列举出哪些情况可能导致判断驾驶顾客车辆的司机处于酒醉状态?]'}
# 285 {'question': '问题：在紧急情况下，如果车辆出现故障导致无法正常解锁和锁止车门，但没有备用机械钥匙，驾驶员应该如何应对？', 'answer': '在紧急情况下，如果车辆出现故障导致无法正常解锁和锁止车门，且没有备用机械钥匙，根据给定的资料，驾驶员可以采取以下应对策略：\n\n1. **紧急道路救援服务**：如果车辆在保修期内（4年或100,000公里范围内），可以联系Lynk&Co领克中心的紧急道路救援服务，他们可能会根据具体情况提供帮助。\n\n2. **使用车内机械钥匙**：如果车辆故障但车门未完全锁死，可以尝试按照第335页的说明使用车内的机械钥匙来解锁或锁止车门。\n\n3. **联系当地救援机构**：如果车辆完全无法解锁，且救援服务无法立即提供帮助，可以联系当地的交警或政府指定的拖车服务商，根据第332页的说明，将车辆拖至安全地点。\n\n4. **遥控钥匙应急操作**：根据第41页的内容，如果遥控钥匙因为电池耗尽或其他原因无法正常工作，可以尝试使用无钥匙进入系统或遥控钥匙上的按键进行操作。\n\n5. **现场简单故障排除**：如果故障相对简单，Lynk&Co领克中心会派出专业技师到现场解决问题（第332页）。\n\n然而，如果以上策略都无法实施，且没有携带备用机械钥匙，驾驶员可能需要等待救援服务或联系专业的开锁服务。\n\n需要注意的是，在实施任何措施之前，应确保遵守当地法律法规，并在必要时联系相关执法机构。结合给定的资料，上述策略是在紧急情况下，驾驶员在没有备用机械钥匙时可以尝试的方法。', 'reference': 'page_334', 'question_keywords': '紧急情况 车辆故障 无法解锁 锁止车门 备用机械钥匙 驾驶员 应对', 'question_rewriting': '[在紧急状况下,车辆出现故障使得车门无法锁定或解锁,若没有额外的机械钥匙,驾驶员可以采取哪些措施?, 面临紧急状况时,如果因为车辆问题导致车门无法正常上锁或解锁,且没有携带备用的机械钥匙,驾驶员有哪些应对策略?]'}
# 286 {'question': '在紧急情况下，如何手动解锁充电枪？', 'answer': '在紧急情况下，如果您需要手动解锁充电枪，可以按照以下步骤操作：\n\n1. 打开前机舱盖。\n2. 拆除发动机舱左侧装饰罩。\n3. 沿箭头方向拨动控制杆，解锁尾门。用合适的工具拆除塑料卡扣，松开装饰罩的卡扣，拆除装饰罩。\n4. 找到位于左侧发动机舱的应急解锁拉线。\n5. 一手握住圆柱卡扣，另一只手拉动应急解锁拉线。\n6. 按压充电枪解锁按钮，拔出充电枪。\n\n注意！在拉动应急解锁拉线时，直至拉线拉不动或听到电子锁解锁声音后，停止操作，防止机械损伤。\n\n如果尝试上述方法还是无法解锁充电枪，请联系Lynk&Co领克中心寻求帮助。', 'reference': 'page_336', 'question_keywords': '紧急情况 手动解锁 充电枪', 'question_rewriting': '[在紧急情况下,我应如何操作才能手动打开充电枪的锁?, 遇到紧急情况时,手动释放充电枪的锁定方式是怎样的?]'}
# 287 {'question': '在紧急情况下，如果车辆充电时发生突发状况，导致无法拔出充电口里的充电枪，您可通过应急解锁拉线手动解锁充电枪。那么，如果遇到无法解锁充电枪的情况，应该如何正确地操作应急解锁拉线以解锁充电枪呢？', 'answer': '在紧急情况下，如果遇到无法从充电口拔出充电枪的状况，可以按照以下步骤正确操作应急解锁拉线以解锁充电枪：\n\n1. 打开前机舱盖。\n2. 拆除发动机舱左侧装饰罩。\n3. 沿箭头方向拨动控制杆，解锁尾门。\n4. 使用合适的工具拆除塑料卡扣，松开装饰罩的卡扣，拆除装饰罩。\n5. 握住圆柱卡扣，另一只手拉动应急解锁拉线。\n6. 在拉动应急解锁拉线时，直至拉线拉不动或听到电子锁解锁声音后，停止操作，防止机械损伤。\n7. 按压充电枪解锁按钮，拔出充电枪。\n\n注意：若尝试上述方法还是无法解锁充电枪，请联系Lynk&Co领克中心寻求帮助。在操作应急解锁拉线时，务必小心谨慎，避免造成不必要的损伤。', 'reference': 'page_336', 'question_keywords': '紧急情况 充电口 充电枪 应急解锁拉线 手动解锁 操作 解锁充电枪', 'question_rewriting': '[在紧急状况下,若车辆充电时遇到意外导致无法从充电口移除充电枪,可以使用应急解锁拉线手动释放它。那么,面对不能解锁充电枪的情形,怎样恰当使用应急解锁拉线来解决这个问题?, 当在紧急事件中遇到充电枪不能从充电口取出时,可以借助应急解锁拉线进行手动解锁。请指导,在无法手动解锁充电枪时,如何准确使用该应急解锁拉线?]'}
# 288 {'question': '在紧急情况下，如何确保安全地将车辆牵引至平板拖车？', 'answer': '在紧急情况下，为确保安全地将车辆牵引至平板拖车，请按照以下步骤操作：\n\n1. 确保车辆处于静止状态，并将变速器挂入空挡（N）。\n   \n2. 解除电子驻车制动（EPB）功能。您可以通过中央显示屏中的“车辆设置”-“其他”关闭EPBAUTO功能，然后踩下制动踏板，将变速器挂入空挡（N），接着长按点火开关使车辆熄火。\n\n3. 牵引车辆至平板拖车前，确保四轮离地，使用平板拖车进行牵引。\n\n4. 牵引车辆时，请确保没有任何人或物体在拖车后面。\n\n5. 牵引完毕后，将变速器挂入驻车挡（P）并启用电子驻车制动（EPB），以确保车辆在平板拖车上的稳定性。\n\n6. 在进行牵引操作前，请穿上安全背心并设置三角警示牌，以警示其他道路使用者，保证人身安全。\n\n7. 遵守本地关于安全背心和三角警示牌使用的相关要求。\n\n8. 注意，禁止使用错误的牵引方式，如以后轮滚动方式牵引、抬起前车体/底盘部分而非车轮、刚性拖拽等。\n\n按照这些步骤，在紧急情况下可以确保车辆安全地被牵引至平板拖车。', 'reference': 'page_338', 'question_keywords': '紧急情况 确保安全 车辆牵引 平板拖车', 'question_rewriting': '[如何在紧急情况下安全地拖引车辆上平板拖车?, 在必须迅速行动的情况下,怎样才能保证把车辆安全地拉上拖车?]'}
# 289 {'question': '在雨雾天气下，在高速公路上应该将三角警示牌设置在车后多少米以外？', 'answer': '在雨雾天气下，在高速公路上应该将三角警示牌设置在车后200米以外。', 'reference': 'page_340', 'question_keywords': '雨雾天气 高速公路 三角警示牌 车后 多少米以外', 'question_rewriting': '[\n    在雨雾天气中,在高速公路上放置三角警告标志,应该保持多远的车后距离?\n    在恶劣的雨雾天气条件下,驾车在高速公路上时,三角警告标志应该放置在车辆后方多远的位置?\n]'}
# 290 {'question': '在雨雾天气条件下，如果无法找到合适的地方设置三角警示牌，应该如何处理？', 'answer': '在雨雾天气条件下，如果无法找到合适的地方设置三角警示牌，根据给定的资料，您应该尽可能在车辆后方的安全距离外放置三角警示牌。根据资料中的说明，在雨雾天气里，三角警示牌应该设置在车后150m以外，如果条件允许，最好能提升到200m。\n\n但如果确实找不到合适的位置，您应该采取以下措施来确保安全：\n1. 确保车辆尽可能靠边停放，不要妨碍交通。\n2. 打开危险报警闪光灯，以增加车辆的可见性。\n3. 如果可能，穿上安全背心以增加自己的可见性。\n4. 尽量远离车辆，在安全的地点等待救援。\n5. 如果有条件，可以尝试使用其他物品（如反光背心、手电筒等）来增加警示效果。\n6. 及时联系救援服务，并告知他们现场的具体情况。\n\n请务必遵守当地的安全规定和法律法规，在确保自身安全的情况下采取相应措施。', 'reference': 'page_340', 'question_keywords': '雨雾天气条件 三角警示牌 处理\n', 'question_rewriting': '[在雨雾天气中,如果没有合适的地点放置警示三角牌,该如何是好?, 雨雾天气里,遇到无处放置三角警示牌的情况,应该采取哪些措施?]'}
# 291 {'question': '在紧急情况下使用补胎套装时，应如何确保轮胎的气压处于适当范围？', 'answer': '在紧急情况下使用补胎套装时，确保轮胎气压处于适当范围的方法如下：\n\n1. 使用补胎套装前，首先要确定轮胎的推荐胎压规格，这通常可以在轮胎侧壁或者车辆的用户手册中找到。\n\n2. 按照补胎套装的说明操作，将电动充气泵气管与补胎液气门嘴连接，并确保连接牢靠。\n\n3. 将电源接头插入车载12V电源并启动车辆，将电动充气泵开关拨到ON位置，开始充气。\n\n4. 在充气过程中，要监控压力表上的压力，确保轮胎气压在最低1.8bar至最大3.2bar的范围内。如果轮胎压力过高，使用减压阀释放一些空气。\n\n5. 充气完成后，关闭电动充气泵，并断开电源接头。\n\n6. 在补胎后，以不超过80km/h的速度行驶约3km后停车检查轮胎是否漏气。\n\n7. 使用手动的气压计或电动充气泵上的压力表再次检查轮胎气压，确保气压没有下降。\n\n8. 如果轮胎仍然漏气，需要联系Lynk&Co领克中心寻求帮助。\n\n9. 补胎套装使用后，要记得将气门防尘盖重新装上，以避免轮胎气门嘴受到砂砾尘土的损害。\n\n通过以上步骤，可以在紧急补胎后检查并保持轮胎气压在正确的水平。需要注意的是，补胎套装仅适用于临时应急使用，之后应尽快到专业的维修中心对轮胎进行全面的检查和修复。', 'reference': 'page_341', 'question_keywords': '紧急情况 使用 补胎套装 确保 轮胎 气压 适当范围', 'question_rewriting': '[如何在使用紧急补胎套装时维持轮胎适当的气压?, 在紧急补胎后,怎样检查并保持轮胎气压在正确水平?]'}
# 292 {'question': '在紧急情况下，如何正确解锁并打开车辆的充电盖进行充电？', 'answer': '在紧急情况下，如果需要解锁并打开车辆的充电盖进行充电，您应该按照以下步骤操作：\n\n1. 确认车辆已经处于熄火状态。\n2. 如果因为车辆整车断电或电子锁机械故障等原因导致无法正常解锁充电盖，您可以采用应急解锁拉线手动解锁充电枪。\n   - 打开前机舱盖。\n   - 拆除发动机舱左侧装饰罩，这里您会看到应急解锁拉线。\n   - 拉动应急解锁拉线，然后向外推动，打开尾门（这里可能是说明中的笔误，应该是打开充电盖）。\n\n在正常情况下，以下是打开充电盖的步骤：\n\n1. 长按仪表板上的按钮，解锁充电盖。\n2. 打开充电盖，并取下充电插座保护盖。\n\n一旦充电盖打开，您可以根据需要取出直流转接口，并按照正常的充电步骤进行充电。\n\n请注意，只有在正常的充电操作步骤无法执行时，才应使用紧急解锁操作。并且在使用应急解锁拉线时，请确保按照说明书小心操作，避免造成额外的损害。充电时，务必确保遵守所有安全操作指南和警告。如果在紧急情况下无法充电，请联系ZEEKR极氪服务（体验）中心寻求帮助。', 'reference': 'page_289', 'question_keywords': '紧急情况 解锁 车辆 充电盖 充电', 'question_rewriting': '[如何在紧急情况下正确操作以开启车辆的充电盖进行充电?, 在遇到紧急情况时,我应该如何恰当地打开车辆的充电盖并进行充电操作?]'}
# 293 {'question': '问题：在车辆开始充电时，应该先拆除哪个端子以防止火花产生？', 'answer': '在车辆开始充电时，应该先拆除负极端子（3）和黑色跨接电缆，以防止火花产生。这是因为负极通常被认为是更安全的断开点，而且在连接或断开电源时，先断开负极可以减少产生电火花的可能性。请确保在操作过程中严格遵守相关的安全指南和步骤。', 'reference': 'page_344', 'question_keywords': '车辆 开始 充电 拆除 端子 防止 火花 产生', 'question_rewriting': '[1, 2, 3,在给汽车充电前,应该先移除哪个接头以避免火花发生?, 进行汽车充电前,哪个电池端子需要优先断开来避免产生电火花?, 在车辆充电过程中,如何选择先拆的端子以避免产生火花?]'}
# 294 {'question': '如何正确安装汽车电子标识，以避免影响其功能？', 'answer': '根据给定的资料，正确安装汽车电子标识以避免影响其功能的方法如下：\n\n1. 保持挡风玻璃的洁净和干燥。\n2. 在安装汽车电子标识时，请勿在挡风玻璃上贴膜或粘贴金属材料，以确保标识的规范安装和数据的有效读取。\n3. 避免将汽车电子标识安装在内后视镜安装支架、传感器支架等可能会遮挡的地方。\n4. 确保标识没有被遮挡、挤压或拆卸。\n\n遵循这些指导原则可以确保汽车电子标识的性能不受损害，并且能够正常工作。', 'reference': 'page_348', 'question_keywords': '安装 汽车电子标识 影响 功能', 'question_rewriting': '[怎样正确地装配汽车电子标签,防止其功能受影响?, 如何准确放置汽车电子标识,确保其性能不受损害?]'}
# 295 {'question': '请问：如何在不遮挡内后视镜安装支架、传感器支架的情况下，正确安装汽车电子标识？', 'answer': '根据给定的资料，正确安装汽车电子标识时需注意以下几点，以确保不妨碍内后视镜和传感器支架：\n\n1. 请保持挡风玻璃洁净、干燥，不要在安装汽车电子标识处贴膜或粘贴金属材料。\n2. 不要在挡风玻璃上粘贴金属膜。\n3. 安装汽车电子标识时，请确保不被内后视镜安装支架、传感器支架等遮挡。\n4. 请勿遮挡、挤压或拆卸汽车电子标识。\n\n综合以上资料，正确安装汽车电子标识的方法是：在挡风玻璃上选择一个不会影响内后视镜和传感器支架的位置进行安装，确保标识安装稳定且不妨碍视线和传感器的正常工作。如果不确定最佳安装位置，建议咨询专业的领克中心或标识发行机构进行安装。', 'reference': 'page_348', 'question_keywords': '不遮挡 内后视镜 安装支架 传感器支架 正确安装 汽车电子标识', 'question_rewriting': '[如何在不妨碍内后视镜和传感器支架的情况下,正确装配汽车电子标识?, 请教一下：在不遮挡内后视镜与传感器支架的前提下,如何正确地安装汽车电子标识?]'}
# 296 {'question': '问题：根据提供的资料，哪项参数是影响MR6453DCH-EV02车型油耗和排放的主要因素？', 'answer': '根据提供的资料，影响MR6453DCH-EV02车型燃油效率和排放性能的关键参数包括：\n\n1. 车辆载荷\n2. 轮胎气压\n3. 驾驶风格\n4. 车速\n5. 加速度\n\n在MR6453DCH-EV02车型中，决定油耗及排放水平的关键因素同样包括上述参数。这些因素会直接影响车辆的燃油消耗和排放水平。此外，根据第350页的内容，燃油规格和等级也会对油耗和排放产生影响，特别是使用劣质燃油或非Lynk&Co领克认证的添加剂可能会导致损坏或故障，从而影响油耗和排放性能。', 'reference': 'page_350', 'question_keywords': '参数_MR6453DCH-EV02_车型_油耗_排放_主要因素', 'question_rewriting': '[1: 影响MR6453DCH-EV02车型燃油效率和排放性能的关键参数有哪些?,2: 在MR6453DCH-EV02车型中,哪些参数是决定油耗及排放水平的关键因素?]'}
# 297 {'question': '问题：车辆在满载状态下，油耗会有多大的变化？', 'answer': '根据给定的资料，车辆满载时对油耗的影响没有直接的数据说明。资料中提到了装载货物会影响车辆的操控性和稳定性，但并未具体说明满载状态下油耗会增加多少。同时，第350页的技术资料中提到了车辆载荷是影响油耗的一个因素，但并未给出满载与油耗的具体数值关系。\n\n因此，结合给定的资料，无法准确回答车辆在满载状态下油耗会有多大的变化。需要更详细的技术数据或实验结果来支持这一问题的答案。', 'reference': 'page_350', 'question_keywords': '车辆 满载 油耗 变化', 'question_rewriting': '[车辆满载时,油耗会增加多少?, 当车辆承载达到最大时,其对燃油消耗的影响有多大?]'}
# 298 {'question': '请问这些汽车技术缩略语和术语主要用于哪些品牌的车型？', 'answer': '这些汽车技术缩略语和术语主要用于Lynk&Co领克品牌的车型。从给定的资料中，我们可以看到这些术语是与Lynk&Co领克汽车的技术规格和系统相关的，例如EDR（事件数据记录系统）、DPS（驾驶员状态监测系统）、ACC（自适应巡航系统）等。这些缩略语和术语通常出现在Lynk&Co领克提供的车型技术资料和用户手册中，用以描述车辆的功能和特性。至于其他品牌是否也使用这些相同的缩略语和术语，资料中并没有提及，因此无法提供更多信息。', 'reference': 'page_352', 'question_keywords': '汽车技术缩略语 术语 品牌 车型', 'question_rewriting': '[哪些汽车品牌经常使用这些技术缩略语和术语?, 这些技术简写和行业术语一般出现在哪些车系的车型中?]'}
# 299 {'question': '请问公制术语中，"Nm"代表什么单位？', 'answer': '在公制系统中，"Nm"表示的是扭矩的单位，它是牛顿米（Newton metre）的缩写。"Nm"在公制单位中意味着每单位长度产生的旋转力，即力矩。简单来说，就是力作用在物体上并使其旋转的能力的度量。', 'reference': 'page_354', 'question_keywords': '公制术语 "Nm" 单位', 'question_rewriting': '[在公制系统中,"Nm"表示的是哪种量度的单位?, "Nm"在公制单位中意味着什么?]'}
# 300 {'question': '请问在汽车技术中，1牛米（Nm）的力矩等于多少牛顿（N）乘以米（m）？', 'answer': '在汽车技术中，1牛米（Nm）的力矩已经是表示力与作用距离的乘积的单位，它等同于1牛顿（N）乘以1米（m）。所以，1牛米就是1牛顿乘以1米的力矩表现方式，不需要进一步的转换。简单来说：\n\n\\[ 1 \\text{牛米 (Nm)} = 1 \\text{牛顿 (N)} \\times 1 \\text{米 (m)} \\]', 'reference': 'page_354', 'question_keywords': '汽车技术 1牛米 Nm 力矩 牛顿 N 米 m', 'question_rewriting': '[请问在汽车工程里,1牛米怎样用牛顿乘以米来表示?, 在汽车技术领域,如何将1牛米转换成牛顿乘以米的单位?]'}

# %%
with open(f'task10_glm4.json', 'w', encoding='utf8') as up:
    json.dump(task9_questions, up, ensure_ascii=False, indent=4)

# %%
# for query_idx in range(len(task9_questions[59:])):
#     query_idx = query_idx+59
#     prompt= '''你是一个汽车维修和汽车销售的专家，将用户的提问改为含义相近当不相同的句子,将改写后的句子以list的形式返回，不要输出起他无关内容,举一个例子：[改写后的句子1,改写后的句子2...] ：
#     问题：{0}
# '''.format(
#     # ''.join([f'第{i+1}页内容：' + pdf_content[i].replace('\n', '') + '\n' for i in doc_scores.argsort()[-3:]]) ,
#     task9_questions[query_idx]["question"]
# )
#     answer = ask_glm(prompt)['choices'][0]['message']['content']
#     task9_questions[query_idx]['question_rewriting'] = answer
#     print(query_idx,task9_questions[query_idx])

# %% [markdown]
# ### 总结
# - 重新改写后模型得分0.753

# %% [markdown]
# ### 参考文献
# - [美团搜索中查询改写技术的探索与实践](https://tech.meituan.com/2022/02/17/exploration-and-practice-of-query-rewriting-in-meituan-search.html)
